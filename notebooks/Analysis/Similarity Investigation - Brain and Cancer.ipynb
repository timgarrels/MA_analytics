# %%
import networkx as nx

# %%
from pathlib import Path
base = Path("/home/timgarrels/Projects/masterthesis/datasets")
cancer = base / "human_cancer_cutoff_0.935.edgelist"
brain = base / "human_brain_development_cutoff_0.772.edgelist"

# %%
cancer_g = nx.read_edgelist(cancer)
brain_g = nx.read_edgelist(brain)

# %%
cancer_g.number_of_nodes(), cancer_g.number_of_edges()
# Out:
# (485, 1992)

# %%
brain_g.number_of_nodes(), brain_g.number_of_edges()
# Out:
# (539, 1996)

# %%
len([k for k, v in dict(cancer_g.degree).items() if v == 1])
# Out:
# 96

# %%
len([k for k, v in dict(brain_g.degree).items() if v == 1])
# Out:
# 84

# %%
nx.draw(cancer_g)

# %%
nx.draw(brain_g)
