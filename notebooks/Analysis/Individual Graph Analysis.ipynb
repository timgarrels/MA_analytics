# %% [markdown]
# Produce a table oveview on motif, anti-motif, and pmotif detection results for one dataset

# %%
# Pmotif Defintion Config
# Effect Size
CORR_COEF_THRESHOLD = 0.3
# MWU significance
GLOBAL_ALPHA = 0.01
SIG_THRESH = 0.8

# Motif Definition Detection
Z_SCORE_THRESHOLD = 2.5

# %%
from os import listdir
from pathlib import Path

BASE_PATH = Path("/home/timgarrels/Projects/masterthesis/copied_results_data/prelim_analysis/_analysis_out")
datasets = sorted(listdir(BASE_PATH))
datasets
# Out:
# ['0_barabasi_albert_graph_m_1',
#  '0_barabasi_albert_graph_m_2',
#  '0_barabasi_albert_graph_m_3',
#  '0_ferdos_renyi_graph_m_2000',
#  '0_scale_free_graph_a_28_b_7_g_02',
#  '0_scale_free_graph_a_35_b_3_g_35',
#  '0_scale_free_graph_a_65_b_1_g_25',
#  '1_barabasi_albert_graph_m_1',
#  '1_barabasi_albert_graph_m_2',
#  '1_barabasi_albert_graph_m_3',
#  '1_ferdos_renyi_graph_m_2000',
#  '1_scale_free_graph_a_28_b_7_g_02',
#  '1_scale_free_graph_a_35_b_3_g_35',
#  '1_scale_free_graph_a_65_b_1_g_25',
#  '2_barabasi_albert_graph_m_1',
#  '2_barabasi_albert_graph_m_2',
#  '2_barabasi_albert_graph_m_3',
#  '2_ferdos_renyi_graph_m_2000',
#  '2_scale_free_graph_a_28_b_7_g_02',
#  '2_scale_free_graph_a_35_b_3_g_35',
#  '2_scale_free_graph_a_65_b_1_g_25',
#  '3_barabasi_albert_graph_m_1',
#  '3_barabasi_albert_graph_m_2',
#  '3_barabasi_albert_graph_m_3',
#  '3_ferdos_renyi_graph_m_2000',
#  '3_scale_free_graph_a_28_b_7_g_02',
#  '3_scale_free_graph_a_35_b_3_g_35',
#  '3_scale_free_graph_a_65_b_1_g_25',
#  '4_barabasi_albert_graph_m_1',
#  '4_barabasi_albert_graph_m_2',
#  '4_barabasi_albert_graph_m_3',
#  '4_ferdos_renyi_graph_m_2000',
#  '4_scale_free_graph_a_28_b_7_g_02',
#  '4_scale_free_graph_a_35_b_3_g_35',
#  '4_scale_free_graph_a_65_b_1_g_25',
#  'human_brain_development_cutoff_0.772.edgelist',
#  'human_cancer_cutoff_0.935.edgelist',
#  'kaggle_so_tags.edgelist',
#  'kaggle_star_wars.edgelist',
#  'yeastInter_st.txt']

# %%
DATASET = "human_brain_development_cutoff_0.772.edgelist"
# DATASET = 'human_cancer_cutoff_0.935.edgelist'
assert DATASET in datasets

# %%
dataset_label_lookup = {
    "human_brain_development_cutoff_0.772.edgelist": r'\brain',
    'human_cancer_cutoff_0.935.edgelist': r'\cancer'
}

# %%
from pmotif_lib.graphlet_representation import graphlet_classes_from_size, graphlet_class_to_name, get_graphlet_size_from_class

graphlet_classes = list(map(graphlet_class_to_name, graphlet_classes_from_size(4)))
graphlet_classes
# Out:
# ['4-Dash',
#  'Fork',
#  'Spoon',
#  'Square',
#  'Crossed Square',
#  'Double Crossed Square']

# %%
graphlet_classes_from_size(4)
# Out:
# ['0110 1001 1000 0100',
#  '0111 1000 1000 1000',
#  '0111 1010 1100 1000',
#  '0110 1001 1001 0110',
#  '0111 1011 1100 1100',
#  '0111 1011 1101 1110']

# %%
def load_artifacts_obj(dataset: str, graphlet_size: int):
    print(listdir(BASE_PATH / dataset / "artifacts" / str(graphlet_size)))
     
    motifs = []

load_artifacts_obj(datasets[0], 3)
# Out:
# ['report.html', 'local', 'global', 'meta.json']

# %%
import json


def get_table_cell(dataset: str, graphlet_class: str, p_metric_name: str):
    """Produces the cell input for the overview table"""

    graphlet_size = get_graphlet_size_from_class(graphlet_class)
    graphlet_class_name = graphlet_class_to_name(graphlet_class)
    base_path = BASE_PATH / dataset / "artifacts" / str(graphlet_size) / "global"
        
    with open(base_path / f"{graphlet_class_name}_frequency_split.json", "r") as f:
        data = json.load(f)
        z_score = data["z-score"]
    is_motif = z_score > Z_SCORE_THRESHOLD
    is_antimotif = z_score < -Z_SCORE_THRESHOLD
    
    pmetric_dir = base_path / p_metric_name
    with open(pmetric_dir / f"{graphlet_class_name}_pairwise.json", "r") as f:
        pairwise_data = json.load(f)
        
    if pairwise_data["error"] is not None:
        return {"is_motif": is_motif, "is_antimotif": is_antimotif}

    corr_coef_relevant = abs(pairwise_data["mean_corr_coef"]) > CORR_COEF_THRESHOLD
    
    usable_graphs = pairwise_data["real_total"]
    local_alpha = GLOBAL_ALPHA / usable_graphs
    relevant_p_values = [p for p in pairwise_data["p-values"] if p > local_alpha]
    
    percentage_relevant = len(relevant_p_values) / usable_graphs
    mwu_relevant = percentage_relevant < SIG_THRESH
    
    # TODO: P-value significance
    
    
    return {
        "z-score": z_score,
        "is_motif": is_motif,
        "is_antimotif": is_antimotif,
        "pmotif": mwu_relevant and corr_coef_relevant,
        "mwu": mwu_relevant,
        "corr_coef": corr_coef_relevant,
        "r_value": -1 if pairwise_data["mean_corr_coef"] < 0 else 1,
        "corr_coef_value": pairwise_data["mean_corr_coef"],
    }

get_table_cell(datasets[-4], "0111 1011 1101 1110", "degree")
# Out:
# {'z-score': 61.28478497857647,
#  'is_motif': True,
#  'is_antimotif': False,
#  'pmotif': True,
#  'mwu': True,
#  'corr_coef': True,
#  'r_value': 1,
#  'corr_coef_value': 0.4053701335621669}

# %%
import pandas as pd

def create_row(pmetric: str, dataset: str, flag=None):
    graphlet_classes = graphlet_classes_from_size(3) + graphlet_classes_from_size(4)
    
    row = {}
    for gc in graphlet_classes:
        try:
            if flag:
                row[gc] = get_table_cell(dataset, gc, pmetric)[flag]
            else:
                row[gc] = get_table_cell(dataset, gc, pmetric)
        except FileNotFoundError:
            # Dataset was not processed
            row[gc] = 0.6 # "Failed to process"
        except KeyError:
            # Graphlet Class missing
            row[gc] = 0.3

        row["name"] = dataset
    
    df = pd.DataFrame([row])
    df.set_index("name", inplace=True)
    return df

df = create_row("degree", datasets[-4])
df.style.background_gradient(cmap='Blues', axis=None)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0fc9c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fc9c_level0_col0" class="col_heading level0 col0" >011 101 110</th>
#       <th id="T_0fc9c_level0_col1" class="col_heading level0 col1" >011 100 100</th>
#       <th id="T_0fc9c_level0_col2" class="col_heading level0 col2" >0110 1001 1000 0100</th>
#       <th id="T_0fc9c_level0_col3" class="col_heading level0 col3" >0111 1000 1000 1000</th>
#       <th id="T_0fc9c_level0_col4" class="col_heading level0 col4" >0111 1010 1100 1000</th>
#       <th id="T_0fc9c_level0_col5" class="col_heading level0 col5" >0110 1001 1001 0110</th>
#       <th id="T_0fc9c_level0_col6" class="col_heading level0 col6" >0111 1011 1100 1100</th>
#       <th id="T_0fc9c_level0_col7" class="col_heading level0 col7" >0111 1011 1101 1110</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0fc9c_level0_row0" class="row_heading level0 row0" >human_cancer_cutoff_0.935.edgelist</th>
#       <td id="T_0fc9c_row0_col0" class="data row0 col0" >{'z-score': 40.70239434105139, 'is_motif': True, 'is_antimotif': False, 'pmotif': False, 'mwu': True, 'corr_coef': False, 'r_value': 1, 'corr_coef_value': 0.19286772524475218}</td>
#       <td id="T_0fc9c_row0_col1" class="data row0 col1" >{'z-score': -40.702394341051374, 'is_motif': False, 'is_antimotif': True, 'pmotif': False, 'mwu': True, 'corr_coef': False, 'r_value': -1, 'corr_coef_value': -0.08269219298309714}</td>
#       <td id="T_0fc9c_row0_col2" class="data row0 col2" >{'z-score': -49.52133988331319, 'is_motif': False, 'is_antimotif': True, 'pmotif': False, 'mwu': True, 'corr_coef': False, 'r_value': -1, 'corr_coef_value': -0.0733606790423684}</td>
#       <td id="T_0fc9c_row0_col3" class="data row0 col3" >{'z-score': -20.375301281139077, 'is_motif': False, 'is_antimotif': True, 'pmotif': False, 'mwu': True, 'corr_coef': False, 'r_value': -1, 'corr_coef_value': -0.07447880117051663}</td>
#       <td id="T_0fc9c_row0_col4" class="data row0 col4" >{'z-score': 15.432610544053432, 'is_motif': True, 'is_antimotif': False, 'pmotif': False, 'mwu': True, 'corr_coef': False, 'r_value': 1, 'corr_coef_value': 0.09048202415305544}</td>
#       <td id="T_0fc9c_row0_col5" class="data row0 col5" >{'z-score': -10.813506399430471, 'is_motif': False, 'is_antimotif': True, 'pmotif': False, 'mwu': False, 'corr_coef': False, 'r_value': 1, 'corr_coef_value': 0.010746699067605258}</td>
#       <td id="T_0fc9c_row0_col6" class="data row0 col6" >{'z-score': 28.121057023117427, 'is_motif': True, 'is_antimotif': False, 'pmotif': False, 'mwu': True, 'corr_coef': False, 'r_value': 1, 'corr_coef_value': 0.24400986889526147}</td>
#       <td id="T_0fc9c_row0_col7" class="data row0 col7" >{'z-score': 61.28478497857647, 'is_motif': True, 'is_antimotif': False, 'pmotif': True, 'mwu': True, 'corr_coef': True, 'r_value': 1, 'corr_coef_value': 0.4053701335621669}</td>
#     </tr>
#   </tbody>
# </table>

# %%
def get_dataframe(dataset, flag="mwu"):
    metric_name_lookup = {
        'graph module participation ratio': "MPR",
        'degree': "Degree",
        'min normalized anchor hop distance': "HD (min)",
        'max normalized anchor hop distance': "HD (max)",
        'mean normalized anchor hop distance': "HD (mean)",
    }
    rows = []

    for metric, metric_label in metric_name_lookup.items():
        row = create_row(metric, dataset, flag=flag)
        row[r"\pmetric"] = metric_label
        row.set_index(r"\pmetric", inplace=True)
        rows.append(row)

    motif_row = create_row(metric, dataset, flag="is_motif")
    motif_row[r"\pmetric"] = "Network Motif"
    motif_row.set_index(r"\pmetric", inplace=True)

    antimotif_row = create_row(metric, dataset, flag="is_antimotif")
    antimotif_row[r"\pmetric"] = "Network Anti-Motif"
    antimotif_row.set_index(r"\pmetric", inplace=True)

    rows = [motif_row, antimotif_row] + rows

    df = pd.concat(rows)

    df = df.replace(True, 1).replace(False, 0)
    df = df.rename(graphlet_class_to_name, axis=1)

    p1 = pd.concat([df.iloc[[0]]], keys=['Motif'], names=["Detection"])
    p2 = pd.concat([df.iloc[[1]]], keys=['Anti-Motif'], names=["Detection"])
    p3 = pd.concat([df.iloc[[2, 3, 4, 5, 6]]], keys=[r"\pmotif"], names=["Detection"])

    df = pd.concat([p1, p2, p3])
    df = df.rename(index={'Network Motif': '-', "Network Anti-Motif": "-"})
    
    return df

# %%
def turn_styler_to_latex(styler):
    text = styler.to_latex()
    # extract colors
    parts = text.split("#")
    colors = {p[:6] for p in parts[1:]}
    color_definitions = [
        r"\definecolor{" + c + "}{HTML}{" + c + "}"
        for c in colors
    ]
    print("\n".join(color_definitions))
    print()
    
    # Replace commands
    for c in colors:
        text = text.replace(r"\background-color#" + c, r"\cellcolor{" + c + "}")
        text = text.replace(r"\color#" + c, r"\color{" + c + "}")
        
    # Add vertical lines
    text = text.replace(r"begin{tabular}{llr", "begin{tabular}{ll|r")
    # Add horizontal lines
    lines = text.split("\n")
    addadge = "\n" + r"\hline" + "\n"
    
    ne_lines = []
    for l in lines:
        if (r"Detection & \pmetric" in l) or ("Motif & -" in l) or ("Anti-Motif & -" in l):
            l += addadge
        ne_lines.append(l)
    text = "\n".join(ne_lines)
    
    # Add scaling and centering
    text = text.replace(r"\begin{tabular}", r"\begin{adjustbox}{max width=\textwidth}" +"\n" + r"\begin{tabular}")
    text = text.replace(r"\end{tabular}", r"\end{tabular}" + "\n" + r"\end{adjustbox}")
    
    print(text)

# %%
df = get_dataframe(DATASET, "mwu")

styler = pd.io.formats.style.Styler(df)
styler.background_gradient(cmap='Greens', axis=None)
styler.set_caption(f"{dataset_label_lookup[DATASET]}, MWU")

styler
# Out:
# <style type="text/css">
# #T_7dfe9_row0_col0, #T_7dfe9_row0_col4, #T_7dfe9_row0_col6, #T_7dfe9_row0_col7, #T_7dfe9_row1_col1, #T_7dfe9_row1_col2, #T_7dfe9_row1_col3, #T_7dfe9_row1_col5, #T_7dfe9_row2_col0, #T_7dfe9_row2_col1, #T_7dfe9_row2_col2, #T_7dfe9_row2_col3, #T_7dfe9_row2_col4, #T_7dfe9_row2_col5, #T_7dfe9_row2_col6, #T_7dfe9_row2_col7, #T_7dfe9_row3_col0, #T_7dfe9_row3_col1, #T_7dfe9_row3_col2, #T_7dfe9_row3_col3, #T_7dfe9_row3_col4, #T_7dfe9_row3_col6, #T_7dfe9_row3_col7, #T_7dfe9_row4_col0, #T_7dfe9_row4_col2, #T_7dfe9_row4_col3, #T_7dfe9_row4_col4, #T_7dfe9_row4_col5, #T_7dfe9_row4_col6, #T_7dfe9_row5_col0, #T_7dfe9_row5_col1, #T_7dfe9_row5_col2, #T_7dfe9_row5_col3, #T_7dfe9_row5_col4, #T_7dfe9_row5_col5, #T_7dfe9_row5_col6, #T_7dfe9_row6_col0, #T_7dfe9_row6_col1, #T_7dfe9_row6_col2, #T_7dfe9_row6_col3, #T_7dfe9_row6_col4, #T_7dfe9_row6_col5, #T_7dfe9_row6_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_7dfe9_row0_col1, #T_7dfe9_row0_col2, #T_7dfe9_row0_col3, #T_7dfe9_row0_col5, #T_7dfe9_row1_col0, #T_7dfe9_row1_col4, #T_7dfe9_row1_col6, #T_7dfe9_row1_col7, #T_7dfe9_row3_col5, #T_7dfe9_row4_col1, #T_7dfe9_row4_col7, #T_7dfe9_row5_col7, #T_7dfe9_row6_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_7dfe9">
#   <caption>\brain, MWU</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7dfe9_level0_col0" class="col_heading level0 col0" >Triangle</th>
#       <th id="T_7dfe9_level0_col1" class="col_heading level0 col1" >3-Dash</th>
#       <th id="T_7dfe9_level0_col2" class="col_heading level0 col2" >4-Dash</th>
#       <th id="T_7dfe9_level0_col3" class="col_heading level0 col3" >Fork</th>
#       <th id="T_7dfe9_level0_col4" class="col_heading level0 col4" >Spoon</th>
#       <th id="T_7dfe9_level0_col5" class="col_heading level0 col5" >Square</th>
#       <th id="T_7dfe9_level0_col6" class="col_heading level0 col6" >Crossed Square</th>
#       <th id="T_7dfe9_level0_col7" class="col_heading level0 col7" >Double Crossed Square</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Detection</th>
#       <th class="index_name level1" >\pmetric</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7dfe9_level0_row0" class="row_heading level0 row0" >Motif</th>
#       <th id="T_7dfe9_level1_row0" class="row_heading level1 row0" >-</th>
#       <td id="T_7dfe9_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7dfe9_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_7dfe9_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_7dfe9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7dfe9_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_7dfe9_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_7dfe9_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_7dfe9_row0_col7" class="data row0 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7dfe9_level0_row1" class="row_heading level0 row1" >Anti-Motif</th>
#       <th id="T_7dfe9_level1_row1" class="row_heading level1 row1" >-</th>
#       <td id="T_7dfe9_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_7dfe9_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_7dfe9_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_7dfe9_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_7dfe9_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_7dfe9_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_7dfe9_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_7dfe9_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7dfe9_level0_row2" class="row_heading level0 row2" rowspan="5">\pmotif</th>
#       <th id="T_7dfe9_level1_row2" class="row_heading level1 row2" >MPR</th>
#       <td id="T_7dfe9_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_7dfe9_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_7dfe9_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_7dfe9_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_7dfe9_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_7dfe9_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_7dfe9_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_7dfe9_row2_col7" class="data row2 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7dfe9_level1_row3" class="row_heading level1 row3" >Degree</th>
#       <td id="T_7dfe9_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_7dfe9_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_7dfe9_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_7dfe9_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_7dfe9_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_7dfe9_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_7dfe9_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_7dfe9_row3_col7" class="data row3 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7dfe9_level1_row4" class="row_heading level1 row4" >HD (min)</th>
#       <td id="T_7dfe9_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_7dfe9_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_7dfe9_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_7dfe9_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_7dfe9_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_7dfe9_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_7dfe9_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_7dfe9_row4_col7" class="data row4 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7dfe9_level1_row5" class="row_heading level1 row5" >HD (max)</th>
#       <td id="T_7dfe9_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_7dfe9_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_7dfe9_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_7dfe9_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_7dfe9_row5_col4" class="data row5 col4" >1</td>
#       <td id="T_7dfe9_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_7dfe9_row5_col6" class="data row5 col6" >1</td>
#       <td id="T_7dfe9_row5_col7" class="data row5 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7dfe9_level1_row6" class="row_heading level1 row6" >HD (mean)</th>
#       <td id="T_7dfe9_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_7dfe9_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_7dfe9_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_7dfe9_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_7dfe9_row6_col4" class="data row6 col4" >1</td>
#       <td id="T_7dfe9_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_7dfe9_row6_col6" class="data row6 col6" >1</td>
#       <td id="T_7dfe9_row6_col7" class="data row6 col7" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = get_dataframe(DATASET, "corr_coef")

styler = pd.io.formats.style.Styler(df)
styler.background_gradient(cmap='Greens', axis=None)
styler.set_caption(f"{dataset_label_lookup[DATASET]}, corr_coef")

styler
# Out:
# <style type="text/css">
# #T_7cd7f_row0_col0, #T_7cd7f_row0_col4, #T_7cd7f_row0_col6, #T_7cd7f_row0_col7, #T_7cd7f_row1_col1, #T_7cd7f_row1_col2, #T_7cd7f_row1_col3, #T_7cd7f_row1_col5, #T_7cd7f_row2_col0, #T_7cd7f_row2_col1, #T_7cd7f_row2_col2, #T_7cd7f_row2_col3, #T_7cd7f_row2_col4, #T_7cd7f_row2_col5, #T_7cd7f_row2_col6, #T_7cd7f_row2_col7, #T_7cd7f_row3_col7, #T_7cd7f_row5_col1, #T_7cd7f_row5_col2, #T_7cd7f_row5_col3, #T_7cd7f_row5_col4, #T_7cd7f_row5_col5, #T_7cd7f_row5_col6, #T_7cd7f_row6_col1, #T_7cd7f_row6_col2, #T_7cd7f_row6_col3, #T_7cd7f_row6_col4, #T_7cd7f_row6_col5, #T_7cd7f_row6_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_7cd7f_row0_col1, #T_7cd7f_row0_col2, #T_7cd7f_row0_col3, #T_7cd7f_row0_col5, #T_7cd7f_row1_col0, #T_7cd7f_row1_col4, #T_7cd7f_row1_col6, #T_7cd7f_row1_col7, #T_7cd7f_row3_col0, #T_7cd7f_row3_col1, #T_7cd7f_row3_col2, #T_7cd7f_row3_col3, #T_7cd7f_row3_col4, #T_7cd7f_row3_col5, #T_7cd7f_row3_col6, #T_7cd7f_row4_col0, #T_7cd7f_row4_col1, #T_7cd7f_row4_col2, #T_7cd7f_row4_col3, #T_7cd7f_row4_col4, #T_7cd7f_row4_col5, #T_7cd7f_row4_col6, #T_7cd7f_row4_col7, #T_7cd7f_row5_col0, #T_7cd7f_row5_col7, #T_7cd7f_row6_col0, #T_7cd7f_row6_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_7cd7f">
#   <caption>\brain, corr_coef</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7cd7f_level0_col0" class="col_heading level0 col0" >Triangle</th>
#       <th id="T_7cd7f_level0_col1" class="col_heading level0 col1" >3-Dash</th>
#       <th id="T_7cd7f_level0_col2" class="col_heading level0 col2" >4-Dash</th>
#       <th id="T_7cd7f_level0_col3" class="col_heading level0 col3" >Fork</th>
#       <th id="T_7cd7f_level0_col4" class="col_heading level0 col4" >Spoon</th>
#       <th id="T_7cd7f_level0_col5" class="col_heading level0 col5" >Square</th>
#       <th id="T_7cd7f_level0_col6" class="col_heading level0 col6" >Crossed Square</th>
#       <th id="T_7cd7f_level0_col7" class="col_heading level0 col7" >Double Crossed Square</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Detection</th>
#       <th class="index_name level1" >\pmetric</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7cd7f_level0_row0" class="row_heading level0 row0" >Motif</th>
#       <th id="T_7cd7f_level1_row0" class="row_heading level1 row0" >-</th>
#       <td id="T_7cd7f_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7cd7f_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_7cd7f_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_7cd7f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7cd7f_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_7cd7f_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_7cd7f_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_7cd7f_row0_col7" class="data row0 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7cd7f_level0_row1" class="row_heading level0 row1" >Anti-Motif</th>
#       <th id="T_7cd7f_level1_row1" class="row_heading level1 row1" >-</th>
#       <td id="T_7cd7f_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_7cd7f_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_7cd7f_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_7cd7f_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_7cd7f_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_7cd7f_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_7cd7f_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_7cd7f_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7cd7f_level0_row2" class="row_heading level0 row2" rowspan="5">\pmotif</th>
#       <th id="T_7cd7f_level1_row2" class="row_heading level1 row2" >MPR</th>
#       <td id="T_7cd7f_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_7cd7f_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_7cd7f_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_7cd7f_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_7cd7f_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_7cd7f_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_7cd7f_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_7cd7f_row2_col7" class="data row2 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7cd7f_level1_row3" class="row_heading level1 row3" >Degree</th>
#       <td id="T_7cd7f_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_7cd7f_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_7cd7f_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_7cd7f_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_7cd7f_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_7cd7f_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_7cd7f_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_7cd7f_row3_col7" class="data row3 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7cd7f_level1_row4" class="row_heading level1 row4" >HD (min)</th>
#       <td id="T_7cd7f_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_7cd7f_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_7cd7f_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_7cd7f_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_7cd7f_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_7cd7f_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_7cd7f_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_7cd7f_row4_col7" class="data row4 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7cd7f_level1_row5" class="row_heading level1 row5" >HD (max)</th>
#       <td id="T_7cd7f_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_7cd7f_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_7cd7f_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_7cd7f_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_7cd7f_row5_col4" class="data row5 col4" >1</td>
#       <td id="T_7cd7f_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_7cd7f_row5_col6" class="data row5 col6" >1</td>
#       <td id="T_7cd7f_row5_col7" class="data row5 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7cd7f_level1_row6" class="row_heading level1 row6" >HD (mean)</th>
#       <td id="T_7cd7f_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_7cd7f_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_7cd7f_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_7cd7f_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_7cd7f_row6_col4" class="data row6 col4" >1</td>
#       <td id="T_7cd7f_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_7cd7f_row6_col6" class="data row6 col6" >1</td>
#       <td id="T_7cd7f_row6_col7" class="data row6 col7" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = get_dataframe(DATASET, "pmotif")

styler = pd.io.formats.style.Styler(df)
styler.background_gradient(cmap='Greens', axis=None)
styler.set_caption(r"Overview over the motif and \pmotif classifications in the " + f"{dataset_label_lookup[DATASET]} Dataset")


def brief_graphlet_name(name):
    if name == "Crossed Square":
        return "CSquare"
    if name == "Double Crossed Square":
        return "DCSquare"
    return name

styler.format_index(brief_graphlet_name, axis=1)
styler
# Out:
# <style type="text/css">
# #T_8a741_row0_col0, #T_8a741_row0_col4, #T_8a741_row0_col6, #T_8a741_row0_col7, #T_8a741_row1_col1, #T_8a741_row1_col2, #T_8a741_row1_col3, #T_8a741_row1_col5, #T_8a741_row2_col0, #T_8a741_row2_col1, #T_8a741_row2_col2, #T_8a741_row2_col3, #T_8a741_row2_col4, #T_8a741_row2_col5, #T_8a741_row2_col6, #T_8a741_row2_col7, #T_8a741_row3_col7, #T_8a741_row5_col1, #T_8a741_row5_col2, #T_8a741_row5_col3, #T_8a741_row5_col4, #T_8a741_row5_col5, #T_8a741_row5_col6, #T_8a741_row6_col1, #T_8a741_row6_col2, #T_8a741_row6_col3, #T_8a741_row6_col4, #T_8a741_row6_col5, #T_8a741_row6_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_8a741_row0_col1, #T_8a741_row0_col2, #T_8a741_row0_col3, #T_8a741_row0_col5, #T_8a741_row1_col0, #T_8a741_row1_col4, #T_8a741_row1_col6, #T_8a741_row1_col7, #T_8a741_row3_col0, #T_8a741_row3_col1, #T_8a741_row3_col2, #T_8a741_row3_col3, #T_8a741_row3_col4, #T_8a741_row3_col5, #T_8a741_row3_col6, #T_8a741_row4_col0, #T_8a741_row4_col1, #T_8a741_row4_col2, #T_8a741_row4_col3, #T_8a741_row4_col4, #T_8a741_row4_col5, #T_8a741_row4_col6, #T_8a741_row4_col7, #T_8a741_row5_col0, #T_8a741_row5_col7, #T_8a741_row6_col0, #T_8a741_row6_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_8a741">
#   <caption>Overview over the motif and \pmotif classifications in the \brain Dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a741_level0_col0" class="col_heading level0 col0" >Triangle</th>
#       <th id="T_8a741_level0_col1" class="col_heading level0 col1" >3-Dash</th>
#       <th id="T_8a741_level0_col2" class="col_heading level0 col2" >4-Dash</th>
#       <th id="T_8a741_level0_col3" class="col_heading level0 col3" >Fork</th>
#       <th id="T_8a741_level0_col4" class="col_heading level0 col4" >Spoon</th>
#       <th id="T_8a741_level0_col5" class="col_heading level0 col5" >Square</th>
#       <th id="T_8a741_level0_col6" class="col_heading level0 col6" >CSquare</th>
#       <th id="T_8a741_level0_col7" class="col_heading level0 col7" >DCSquare</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Detection</th>
#       <th class="index_name level1" >\pmetric</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a741_level0_row0" class="row_heading level0 row0" >Motif</th>
#       <th id="T_8a741_level1_row0" class="row_heading level1 row0" >-</th>
#       <td id="T_8a741_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_8a741_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_8a741_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_8a741_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8a741_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_8a741_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_8a741_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_8a741_row0_col7" class="data row0 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8a741_level0_row1" class="row_heading level0 row1" >Anti-Motif</th>
#       <th id="T_8a741_level1_row1" class="row_heading level1 row1" >-</th>
#       <td id="T_8a741_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_8a741_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_8a741_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_8a741_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_8a741_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_8a741_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_8a741_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_8a741_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8a741_level0_row2" class="row_heading level0 row2" rowspan="5">\pmotif</th>
#       <th id="T_8a741_level1_row2" class="row_heading level1 row2" >MPR</th>
#       <td id="T_8a741_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_8a741_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_8a741_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_8a741_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_8a741_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_8a741_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_8a741_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_8a741_row2_col7" class="data row2 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8a741_level1_row3" class="row_heading level1 row3" >Degree</th>
#       <td id="T_8a741_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_8a741_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_8a741_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_8a741_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_8a741_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_8a741_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_8a741_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_8a741_row3_col7" class="data row3 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8a741_level1_row4" class="row_heading level1 row4" >HD (min)</th>
#       <td id="T_8a741_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_8a741_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_8a741_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_8a741_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_8a741_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_8a741_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_8a741_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_8a741_row4_col7" class="data row4 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8a741_level1_row5" class="row_heading level1 row5" >HD (max)</th>
#       <td id="T_8a741_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_8a741_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_8a741_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_8a741_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_8a741_row5_col4" class="data row5 col4" >1</td>
#       <td id="T_8a741_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_8a741_row5_col6" class="data row5 col6" >1</td>
#       <td id="T_8a741_row5_col7" class="data row5 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8a741_level1_row6" class="row_heading level1 row6" >HD (mean)</th>
#       <td id="T_8a741_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_8a741_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_8a741_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_8a741_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_8a741_row6_col4" class="data row6 col4" >1</td>
#       <td id="T_8a741_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_8a741_row6_col6" class="data row6 col6" >1</td>
#       <td id="T_8a741_row6_col7" class="data row6 col7" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
turn_styler_to_latex(styler)
# Out:
# \definecolor{00441b}{HTML}{00441b}
# \definecolor{000000}{HTML}{000000}
# \definecolor{f7fcf5}{HTML}{f7fcf5}
# \definecolor{f1f1f1}{HTML}{f1f1f1}
#
# \begin{table}
# \caption{Overview over the motif and \pmotif classifications in the \brain Dataset}
# \begin{adjustbox}{max width=\textwidth}
# \begin{tabular}{ll|rrrrrrrr}
#  &  & Triangle & 3-Dash & 4-Dash & Fork & Spoon & Square & CSquare & DCSquare \\
# Detection & \pmetric &  &  &  &  &  &  &  &  \\
# \hline
#
# Motif & - & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 \\
# \hline
#
# Anti-Motif & - & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{f7fcf5} \color{000000} 0 \\
# \hline
#
# \multirow[c]{5}{*}{\pmotif} & MPR & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 \\
#  & Degree & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{00441b} \color{f1f1f1} 1 \\
#  & HD (min) & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{f7fcf5} \color{000000} 0 \\
#  & HD (max) & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{f7fcf5} \color{000000} 0 \\
#  & HD (mean) & \cellcolor{f7fcf5} \color{000000} 0 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{00441b} \color{f1f1f1} 1 & \cellcolor{f7fcf5} \color{000000} 0 \\
# \end{tabular}
# \end{adjustbox}
# \end{table}

# %% [markdown]
# human brain: 35/40 significant mwu, 21/40 effect size significant, 21 pmotifs

# %%
for gc in graphlet_classes_from_size(4):
    print(get_table_cell(DATASET, gc, "graph module participation ratio"))
# Out:
# {'z-score': -42.98858325064301, 'is_motif': False, 'is_antimotif': True, 'pmotif': True, 'mwu': True, 'corr_coef': True, 'r_value': 1, 'corr_coef_value': 0.7486966376499276}
# {'z-score': -29.250311223255792, 'is_motif': False, 'is_antimotif': True, 'pmotif': True, 'mwu': True, 'corr_coef': True, 'r_value': 1, 'corr_coef_value': 0.7130727415383292}
# {'z-score': 22.275423435181295, 'is_motif': True, 'is_antimotif': False, 'pmotif': True, 'mwu': True, 'corr_coef': True, 'r_value': 1, 'corr_coef_value': 0.77263824972181}
# {'z-score': -9.724722728470109, 'is_motif': False, 'is_antimotif': True, 'pmotif': True, 'mwu': True, 'corr_coef': True, 'r_value': 1, 'corr_coef_value': 0.8017314709670365}
# {'z-score': 37.233767738830416, 'is_motif': True, 'is_antimotif': False, 'pmotif': True, 'mwu': True, 'corr_coef': True, 'r_value': 1, 'corr_coef_value': 0.8374304404851528}
# {'z-score': 225.54558177519655, 'is_motif': True, 'is_antimotif': False, 'pmotif': True, 'mwu': True, 'corr_coef': True, 'r_value': 1, 'corr_coef_value': 0.9036732455079058}

# %%
"""Analyse with r sign!"""
brain = "human_brain_development_cutoff_0.772.edgelist"
cancer = 'human_cancer_cutoff_0.935.edgelist'

same_df = get_dataframe(brain, "r_value") == get_dataframe(cancer, "r_value")

same_df.replace(True, 1).replace(False, 0).style.background_gradient(axis=None)
# Out:
# <style type="text/css">
# #T_09877_row0_col0, #T_09877_row0_col1, #T_09877_row0_col2, #T_09877_row0_col3, #T_09877_row0_col4, #T_09877_row0_col5, #T_09877_row0_col6, #T_09877_row0_col7, #T_09877_row1_col0, #T_09877_row1_col1, #T_09877_row1_col2, #T_09877_row1_col3, #T_09877_row1_col4, #T_09877_row1_col5, #T_09877_row1_col6, #T_09877_row1_col7, #T_09877_row2_col0, #T_09877_row2_col1, #T_09877_row2_col2, #T_09877_row2_col3, #T_09877_row2_col4, #T_09877_row2_col5, #T_09877_row2_col6, #T_09877_row2_col7, #T_09877_row3_col0, #T_09877_row3_col1, #T_09877_row3_col2, #T_09877_row3_col3, #T_09877_row3_col5, #T_09877_row3_col6, #T_09877_row3_col7, #T_09877_row4_col0, #T_09877_row4_col1, #T_09877_row4_col2, #T_09877_row4_col3, #T_09877_row4_col4, #T_09877_row4_col5, #T_09877_row4_col6, #T_09877_row4_col7, #T_09877_row5_col0, #T_09877_row5_col1, #T_09877_row5_col2, #T_09877_row5_col3, #T_09877_row5_col4, #T_09877_row5_col5, #T_09877_row5_col6, #T_09877_row6_col0, #T_09877_row6_col1, #T_09877_row6_col2, #T_09877_row6_col3, #T_09877_row6_col4, #T_09877_row6_col5, #T_09877_row6_col6, #T_09877_row6_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_09877_row3_col4, #T_09877_row5_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_09877">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09877_level0_col0" class="col_heading level0 col0" >Triangle</th>
#       <th id="T_09877_level0_col1" class="col_heading level0 col1" >3-Dash</th>
#       <th id="T_09877_level0_col2" class="col_heading level0 col2" >4-Dash</th>
#       <th id="T_09877_level0_col3" class="col_heading level0 col3" >Fork</th>
#       <th id="T_09877_level0_col4" class="col_heading level0 col4" >Spoon</th>
#       <th id="T_09877_level0_col5" class="col_heading level0 col5" >Square</th>
#       <th id="T_09877_level0_col6" class="col_heading level0 col6" >Crossed Square</th>
#       <th id="T_09877_level0_col7" class="col_heading level0 col7" >Double Crossed Square</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Detection</th>
#       <th class="index_name level1" >\pmetric</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09877_level0_row0" class="row_heading level0 row0" >Motif</th>
#       <th id="T_09877_level1_row0" class="row_heading level1 row0" >-</th>
#       <td id="T_09877_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_09877_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_09877_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_09877_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_09877_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_09877_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_09877_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_09877_row0_col7" class="data row0 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_09877_level0_row1" class="row_heading level0 row1" >Anti-Motif</th>
#       <th id="T_09877_level1_row1" class="row_heading level1 row1" >-</th>
#       <td id="T_09877_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_09877_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_09877_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_09877_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_09877_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_09877_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_09877_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_09877_row1_col7" class="data row1 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_09877_level0_row2" class="row_heading level0 row2" rowspan="5">\pmotif</th>
#       <th id="T_09877_level1_row2" class="row_heading level1 row2" >MPR</th>
#       <td id="T_09877_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_09877_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_09877_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_09877_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_09877_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_09877_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_09877_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_09877_row2_col7" class="data row2 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_09877_level1_row3" class="row_heading level1 row3" >Degree</th>
#       <td id="T_09877_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_09877_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_09877_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_09877_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_09877_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_09877_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_09877_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_09877_row3_col7" class="data row3 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_09877_level1_row4" class="row_heading level1 row4" >HD (min)</th>
#       <td id="T_09877_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_09877_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_09877_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_09877_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_09877_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_09877_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_09877_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_09877_row4_col7" class="data row4 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_09877_level1_row5" class="row_heading level1 row5" >HD (max)</th>
#       <td id="T_09877_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_09877_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_09877_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_09877_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_09877_row5_col4" class="data row5 col4" >1</td>
#       <td id="T_09877_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_09877_row5_col6" class="data row5 col6" >1</td>
#       <td id="T_09877_row5_col7" class="data row5 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_09877_level1_row6" class="row_heading level1 row6" >HD (mean)</th>
#       <td id="T_09877_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_09877_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_09877_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_09877_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_09877_row6_col4" class="data row6 col4" >1</td>
#       <td id="T_09877_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_09877_row6_col6" class="data row6 col6" >1</td>
#       <td id="T_09877_row6_col7" class="data row6 col7" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
get_dataframe(brain, "r_value")
# Out:
#                       Triangle  3-Dash  4-Dash  Fork  Spoon  Square
# Detection  \pmetric
# Motif      -                 1       0       0     0      1       0  \
# Anti-Motif -                 0       1       1     1      0       1
# \pmotif    MPR               1       1       1     1      1       1
#            Degree            1      -1      -1    -1     -1       1
#            HD (min)         -1       1       1     1     -1      -1
#            HD (max)          1       1       1     1      1       1
#            HD (mean)         1       1       1     1      1       1
#
#                       Crossed Square  Double Crossed Square
# Detection  \pmetric
# Motif      -                       1                      1
# Anti-Motif -                       0                      0
# \pmotif    MPR                     1                      1
#            Degree                  1                      1
#            HD (min)               -1                     -1
#            HD (max)                1                     -1
#            HD (mean)               1                     -1

# %%
get_dataframe(cancer, "r_value")
# Out:
#                       Triangle  3-Dash  4-Dash  Fork  Spoon  Square
# Detection  \pmetric
# Motif      -                 1       0       0     0      1       0  \
# Anti-Motif -                 0       1       1     1      0       1
# \pmotif    MPR               1       1       1     1      1       1
#            Degree            1      -1      -1    -1      1       1
#            HD (min)         -1       1       1     1     -1      -1
#            HD (max)          1       1       1     1      1       1
#            HD (mean)         1       1       1     1      1       1
#
#                       Crossed Square  Double Crossed Square
# Detection  \pmetric
# Motif      -                       1                      1
# Anti-Motif -                       0                      0
# \pmotif    MPR                     1                      1
#            Degree                  1                      1
#            HD (min)               -1                     -1
#            HD (max)                1                      1
#            HD (mean)               1                     -1

# %%
corr_coef_diff_df = (get_dataframe(brain, "corr_coef_value").apply(abs) - get_dataframe(cancer, "corr_coef_value").apply(abs))
corr_coef_diff_df.style.background_gradient("bwr", axis=None)
# Out:
# <style type="text/css">
# #T_90f1c_row0_col0, #T_90f1c_row0_col1, #T_90f1c_row0_col2, #T_90f1c_row0_col3, #T_90f1c_row0_col4, #T_90f1c_row0_col5, #T_90f1c_row0_col6, #T_90f1c_row0_col7, #T_90f1c_row1_col0, #T_90f1c_row1_col1, #T_90f1c_row1_col2, #T_90f1c_row1_col3, #T_90f1c_row1_col4, #T_90f1c_row1_col5, #T_90f1c_row1_col6, #T_90f1c_row1_col7, #T_90f1c_row4_col2, #T_90f1c_row4_col3 {
#   background-color: #d8d8ff;
#   color: #000000;
# }
# #T_90f1c_row2_col0 {
#   background-color: #b0b0ff;
#   color: #000000;
# }
# #T_90f1c_row2_col1 {
#   background-color: #8080ff;
#   color: #f1f1f1;
# }
# #T_90f1c_row2_col2 {
#   background-color: #6e6eff;
#   color: #f1f1f1;
# }
# #T_90f1c_row2_col3 {
#   background-color: #5c5cff;
#   color: #f1f1f1;
# }
# #T_90f1c_row2_col4 {
#   background-color: #6868ff;
#   color: #f1f1f1;
# }
# #T_90f1c_row2_col5 {
#   background-color: #6c6cff;
#   color: #f1f1f1;
# }
# #T_90f1c_row2_col6 {
#   background-color: #8686ff;
#   color: #f1f1f1;
# }
# #T_90f1c_row2_col7 {
#   background-color: #aeaeff;
#   color: #000000;
# }
# #T_90f1c_row3_col0 {
#   background-color: #ffd2d2;
#   color: #000000;
# }
# #T_90f1c_row3_col1 {
#   background-color: #f0f0ff;
#   color: #000000;
# }
# #T_90f1c_row3_col2 {
#   background-color: #ffe2e2;
#   color: #000000;
# }
# #T_90f1c_row3_col3, #T_90f1c_row6_col7 {
#   background-color: #ffb2b2;
#   color: #000000;
# }
# #T_90f1c_row3_col4 {
#   background-color: #9696ff;
#   color: #f1f1f1;
# }
# #T_90f1c_row3_col5, #T_90f1c_row4_col5, #T_90f1c_row4_col6 {
#   background-color: #e4e4ff;
#   color: #000000;
# }
# #T_90f1c_row3_col6 {
#   background-color: #9e9eff;
#   color: #f1f1f1;
# }
# #T_90f1c_row3_col7 {
#   background-color: #ff5252;
#   color: #f1f1f1;
# }
# #T_90f1c_row4_col0 {
#   background-color: #e2e2ff;
#   color: #000000;
# }
# #T_90f1c_row4_col1 {
#   background-color: #d6d6ff;
#   color: #000000;
# }
# #T_90f1c_row4_col4 {
#   background-color: #dcdcff;
#   color: #000000;
# }
# #T_90f1c_row4_col7 {
#   background-color: #cacaff;
#   color: #000000;
# }
# #T_90f1c_row5_col0 {
#   background-color: #c8c8ff;
#   color: #000000;
# }
# #T_90f1c_row5_col1 {
#   background-color: #ff4848;
#   color: #f1f1f1;
# }
# #T_90f1c_row5_col2 {
#   background-color: #ffa0a0;
#   color: #000000;
# }
# #T_90f1c_row5_col3 {
#   background-color: #ff5454;
#   color: #f1f1f1;
# }
# #T_90f1c_row5_col4 {
#   background-color: #ff2424;
#   color: #f1f1f1;
# }
# #T_90f1c_row5_col5 {
#   background-color: #ff4242;
#   color: #f1f1f1;
# }
# #T_90f1c_row5_col6 {
#   background-color: #ff2626;
#   color: #f1f1f1;
# }
# #T_90f1c_row5_col7 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_90f1c_row6_col0 {
#   background-color: #ccccff;
#   color: #000000;
# }
# #T_90f1c_row6_col1 {
#   background-color: #ffb8b8;
#   color: #000000;
# }
# #T_90f1c_row6_col2 {
#   background-color: #ff7878;
#   color: #f1f1f1;
# }
# #T_90f1c_row6_col3 {
#   background-color: #ff0808;
#   color: #f1f1f1;
# }
# #T_90f1c_row6_col4 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_90f1c_row6_col5 {
#   background-color: #ff6060;
#   color: #f1f1f1;
# }
# #T_90f1c_row6_col6 {
#   background-color: #ff0202;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_90f1c">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90f1c_level0_col0" class="col_heading level0 col0" >Triangle</th>
#       <th id="T_90f1c_level0_col1" class="col_heading level0 col1" >3-Dash</th>
#       <th id="T_90f1c_level0_col2" class="col_heading level0 col2" >4-Dash</th>
#       <th id="T_90f1c_level0_col3" class="col_heading level0 col3" >Fork</th>
#       <th id="T_90f1c_level0_col4" class="col_heading level0 col4" >Spoon</th>
#       <th id="T_90f1c_level0_col5" class="col_heading level0 col5" >Square</th>
#       <th id="T_90f1c_level0_col6" class="col_heading level0 col6" >Crossed Square</th>
#       <th id="T_90f1c_level0_col7" class="col_heading level0 col7" >Double Crossed Square</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Detection</th>
#       <th class="index_name level1" >\pmetric</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90f1c_level0_row0" class="row_heading level0 row0" >Motif</th>
#       <th id="T_90f1c_level1_row0" class="row_heading level1 row0" >-</th>
#       <td id="T_90f1c_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_90f1c_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_90f1c_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_90f1c_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_90f1c_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_90f1c_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_90f1c_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_90f1c_row0_col7" class="data row0 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_90f1c_level0_row1" class="row_heading level0 row1" >Anti-Motif</th>
#       <th id="T_90f1c_level1_row1" class="row_heading level1 row1" >-</th>
#       <td id="T_90f1c_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_90f1c_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_90f1c_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_90f1c_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_90f1c_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_90f1c_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_90f1c_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_90f1c_row1_col7" class="data row1 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_90f1c_level0_row2" class="row_heading level0 row2" rowspan="5">\pmotif</th>
#       <th id="T_90f1c_level1_row2" class="row_heading level1 row2" >MPR</th>
#       <td id="T_90f1c_row2_col0" class="data row2 col0" >-0.037412</td>
#       <td id="T_90f1c_row2_col1" class="data row2 col1" >-0.080270</td>
#       <td id="T_90f1c_row2_col2" class="data row2 col2" >-0.098416</td>
#       <td id="T_90f1c_row2_col3" class="data row2 col3" >-0.114044</td>
#       <td id="T_90f1c_row2_col4" class="data row2 col4" >-0.102875</td>
#       <td id="T_90f1c_row2_col5" class="data row2 col5" >-0.099879</td>
#       <td id="T_90f1c_row2_col6" class="data row2 col6" >-0.074789</td>
#       <td id="T_90f1c_row2_col7" class="data row2 col7" >-0.038317</td>
#     </tr>
#     <tr>
#       <th id="T_90f1c_level1_row3" class="row_heading level1 row3" >Degree</th>
#       <td id="T_90f1c_row3_col0" class="data row3 col0" >0.076820</td>
#       <td id="T_90f1c_row3_col1" class="data row3 col1" >0.022576</td>
#       <td id="T_90f1c_row3_col2" class="data row3 col2" >0.062147</td>
#       <td id="T_90f1c_row3_col3" class="data row3 col3" >0.106868</td>
#       <td id="T_90f1c_row3_col4" class="data row3 col4" >-0.061253</td>
#       <td id="T_90f1c_row3_col5" class="data row3 col5" >0.010536</td>
#       <td id="T_90f1c_row3_col6" class="data row3 col6" >-0.053396</td>
#       <td id="T_90f1c_row3_col7" class="data row3 col7" >0.195721</td>
#     </tr>
#     <tr>
#       <th id="T_90f1c_level1_row4" class="row_heading level1 row4" >HD (min)</th>
#       <td id="T_90f1c_row4_col0" class="data row4 col0" >0.009822</td>
#       <td id="T_90f1c_row4_col1" class="data row4 col1" >-0.001306</td>
#       <td id="T_90f1c_row4_col2" class="data row4 col2" >0.000565</td>
#       <td id="T_90f1c_row4_col3" class="data row4 col3" >0.000711</td>
#       <td id="T_90f1c_row4_col4" class="data row4 col4" >0.004109</td>
#       <td id="T_90f1c_row4_col5" class="data row4 col5" >0.011553</td>
#       <td id="T_90f1c_row4_col6" class="data row4 col6" >0.010680</td>
#       <td id="T_90f1c_row4_col7" class="data row4 col7" >-0.012861</td>
#     </tr>
#     <tr>
#       <th id="T_90f1c_level1_row5" class="row_heading level1 row5" >HD (max)</th>
#       <td id="T_90f1c_row5_col0" class="data row5 col0" >-0.015256</td>
#       <td id="T_90f1c

# %%
differences = [0.195721,
               0.204417, 0.101640, 0.123024, 0.160043, 0.194265, 0.264475,
               0.237215, 0.272027, 0.210343, 0.183526, 0.235685, 0.268464]
from statistics import mean
mean(differences)
# Out:
# 0.20391115384615385

# %%
corr_coef_diff_df.index
# Out:
# MultiIndex([(     'Motif',         '-'),
#             ('Anti-Motif',         '-'),
#             (   '\pmotif',       'MPR'),
#             (   '\pmotif',    'Degree'),
#             (   '\pmotif',  'HD (min)'),
#             (   '\pmotif',  'HD (max)'),
#             (   '\pmotif', 'HD (mean)')],
#            names=['Detection', '\pmetric'])

# %%
corr_coef_diff_df[corr_coef_diff_df.columns].loc[(   '\pmotif',       'MPR')].mean()
# Out:
# -0.08075041182426151
