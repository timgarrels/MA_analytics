# %%
from motif_position_tooling.utils import edge_swapping
import random

random.seed(1)

edge_swapping.swap_edges_markov_chain
# Out:
# <function motif_position_tooling.utils.edge_swapping.swap_edges_markov_chain(g: networkx.classes.graph.Graph, num: int, tries: int)>

# %%
import networkx as nx

g = nx.Graph()
g.add_edge(0, 1)
g.add_edge(1, 2)
g.add_edge(0, 3)
g.add_edge(3, 4)
g.add_edge(0, 5)
g.add_edge(5, 6)

nx.draw(g)
print(nx.diameter(g))
# Out:
# 4

# %%
g_dash = edge_swapping.swap_edges_markov_chain(g, 10, 3)

nx.draw(g_dash)
print(nx.diameter(g_dash))
# Out:
# 5
