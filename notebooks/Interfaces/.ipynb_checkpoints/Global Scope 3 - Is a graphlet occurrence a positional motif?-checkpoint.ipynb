# %% [markdown]
# The idea of this analysis workflow was to check, whether a single graphlet occurrence displays unique properties across random graphs.
# The approach was prototyped as "choose an occurrence, filter all randomized graphs by whether they contain the same occurrence, analyse positional metrics of the occurrence in all left over random graphs compared against occurrences of the same class".
#
# For example, if you choose the occurrence "Triangle 1-2-3", we would check the positional metrics of that triangle against all other triangles, in the original graph, and in all random graphs, which also contain "Triangle 1-2-3".
#
# Due to the randomization, not all random graphs contain the chosen graphlet occurrence.
#
#
# As it turns out, it is rare, that an occurrence survives the randomization process. This makes an analysis a) statistically unreliable, as not enough random graphs are available and b) makes the choice of the occurrence hard.
#
# This could be addressed by either scanning all occurrences for viable individual occurrences. However, this takes a long time.
# Another approach could be to change the randomization by fixing the edges of the chosen occurrence. However, this need further statistical analysis as it changes the null model, and also doe snot fit in the planned workflow, as this would mean re-generation of data (by generating random graphs on demand based on the chosen occurrence).

# %%
assert False, "Difficult to do, not implemented, see above"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 assert False, "Difficult to do, not implemented, see above"
#
# AssertionError: Difficult to do, not implemented, see above

# %%
from pmotifs.analysis_utilities.loading import Result
from pmotifs.config import config

GRAPHLET_SIZE = 3

r = Result.load_result(
    config.DATASET_DIRECTORY /  "yeastInter_st.txt",
    config.EXPERIMENT_OUT / "yeastInter_st",
    GRAPHLET_SIZE,
)

g = r.pmotif_graph
df = r.positional_metric_df
# Out:
# Loading graphlet metrics: 100%|███████| 13150/13150 [00:00<00:00, 105241.55it/s]
# Loading anchor nodes: 100%|█████████████████| 42/42 [00:00<00:00, 328658.15it/s]
# Loading anchor node shortest paths: 100%|████| 42/42 [00:00<00:00, 46006.99it/s]
# Loading graph modules: 100%|████████████████| 27/27 [00:00<00:00, 179755.89it/s]

# %%
randomized_results = Result.load_randomized_results(g, GRAPHLET_SIZE, supress_tqdm=True)
# Out:
# Loading Randomized Results: 100%|███████████| 1000/1000 [00:49<00:00, 20.25it/s]

# %%
randomized_results = {
    r.pmotif_graph: r.positional_metric_df
    for r in randomized_results
}

# %% [markdown]
# # Analysis

# %%
METRIC_NAME = "degree"

# %%
# Extract Distribution of Metric for one dataframe
def extract_metric_distribution(df, metric_name):
    return dict(df.groupby("graphlet_class").agg(list)[metric_name])

extract_metric_distribution(df, METRIC_NAME)
# Out:
# {'011 100 100': [10,
#   8,
#   9,
#   11,
#   17,
#   8,
#   11,
#   11,
#   74,
#   16,
#   5,
#   4,
#   3,
#   28,
#   6,
#   6,
#   34,
#   11,
#   13,
#   24,
#   12,
#   12,
#   14,
#   13,
#   12,
#   13,
#   26,
#   13,
#   16,
#   16,
#   16,
#   16,
#   16,
#   26,
#   18,
#   18,
#   18,
#   16,
#   17,
#   18,
#   20,
#   19,
#   24,
#   18,
#   5,
#   5,
#   11,
#   10,
#   10,
#   12,
#   13,
#   12,
#   10,
#   12,
#   14,
#   18,
#   13,
#   12,
#   11,
#   11,
#   13,
#   14,
#   13,
#   11,
#   13,
#   15,
#   19,
#   14,
#   10,
#   12,
#   13,
#   12,
#   10,
#   12,
#   14,
#   18,
#   13,
#   12,
#   13,
#   12,
#   10,
#   12,
#   14,
#   18,
#   13,
#   37,
#   21,
#   15,
#   14,
#   12,
#   14,
#   16,
#   20,
#   15,
#   50,
#   34,
#   20,
#   15,
#   13,
#   15,
#   17,
#   21,
#   16,
#   20,
#   27,
#   12,
#   14,
#   16,
#   20,
#   15,
#   12,
#   14,
#   18,
#   13,
#   37,
#   15,
#   16,
#   20,
#   15,
#   22,
#   51,
#   24,
#   29,
#   22,
#   17,
#   25,
#   33,
#   18,
#   27,
#   20,
#   21,
#   20,
#   25,
#   21,
#   50,
#   19,
#   20,
#   52,
#   15,
#   15,
#   16,
#   15,
#   19,
#   20,
#   15,
#   16,
#   16,
#   16,
#   15,
#   15,
#   16,
#   16,
#   15,
#   13,
#   47,
#   33,
#   20,
#   22,
#   27,
#   12,
#   22,
#   11,
#   13,
#   12,
#   34,
#   38,
#   25,
#   20,
#   15,
#   26,
#   22,
#   17,
#   27,
#   24,
#   18,
#   17,
#   16,
#   18,
#   17,
#   14,
#   7,
#   6,
#   16,
#   11,
#   10,
#   8,
#   15,
#   40,
#   5,
#   6,
#   15,
#   6,
#   6,
#   7,
#   9,
#   18,
#   6,
#   31,
#   9,
#   19,
#   19,
#   18,
#   25,
#   16,
#   15,
#   15,
#   17,
#   16,
#   17,
#   18,
#   20,
#   16,
#   20,
#   39,
#   39,
#   39,
#   40,
#   41,
#   39,
#   39,
#   46,
#   40,
#   39,
#   40,
#   39,
#   40,
#   42,
#   41,
#   40,
#   40,
#   40,
#   39,
#   39,
#   55,
#   43,
#   44,
#   41,
#   41,
#   53,
#   40,
#   49,
#   41,
#   39,
#   41,
#   40,
#   40,
#   43,
#   44,
#   42,
#   42,
#   45,
#   46,
#   19,
#   33,
#   9,
#   10,
#   8,
#   8,
#   15,
#   12,
#   10,
#   10,
#   11,
#   11,
#   15,
#   17,
#   3,
#   13,
#   14,
#   13,
#   12,
#   17,
#   16,
#   12,
#   13,
#   15,
#   16,
#   24,
#   13,
#   14,
#   16,
#   22,
#   12,
#   21,
#   23,
#   26,
#   13,
#   21,
#   12,
#   12,
#   13,
#   15,
#   8,
#   9,
#   8,
#   8,
#   8,
#   7,
#   7,
#   59,
#   52,
#   53,
#   52,
#   52,
#   52,
#   52,
#   52,
#   52,
#   59,
#   54,
#   54,
#   53,
#   53,
#   53,
#   54,
#   59,
#   52,
#   53,
#   54,
#   54,
#   52,
#   52,
#   53,
#   52,
#   54,
#   54,
#   52,
#   52,
#   54,
#   53,
#   54,
#   52,
#   54,
#   55,
#   52,
#   52,
#   52,
#   55,
#   52,
#   52,
#   52,
#   53,
#   52,
#   54,
#   52,
#   53,
#   52,
#   53,
#   53,
#   53,
#   53,
#   53,
#   3,
#   3,
#   4,
#   3,
#   7,
#   8,
#   7,
#   7,
#   7,
#   6,
#   7,
#   8,
#   7,
#   7,
#   7,
#   8,
#   9,
#   8,
#   8,
#   59,
#   52,
#   53,
#   52,
#   52,
#   52,
#   52,
#   52,
#   52,
#

#   70,
#   70,
#   70,
#   70,
#   70,
#   70,
#   70,
#   70,
#   70,
#   72,
#   76,
#   71,
#   70,
#   72,
#   70,
#   70,
#   70,
#   69,
#   70,
#   69,
#   70,
#   70,
#   70,
#   70,
#   69,
#   69,
#   71,
#   70,
#   70,
#   69,
#   70,
#   73,
#   70,
#   70,
#   69,
#   70,
#   69,
#   69,
#   71,
#   69,
#   70,
#   69,
#   73,
#   69,
#   69,
#   69,
#   69,
#   70,
#   71,
#   73,
#   70,
#   69,
#   74,
#   70,
#   72,
#   69,
#   70,
#   70,
#   69,
#   69,
#   69,
#   70,
#   70,
#   70,
#   72,
#   70,
#   70,
#   69,
#   69,
#   69,
#   70,
#   70,
#   70,
#   70,
#   70,
#   70,
#   70,
#   70,
#   70,
#   72,
#   76,
#   71,
#   70,
#   72,
#   70,
#   70,
#   70,
#   69,
#   70,
#   69,
#   70,
#   70,
#   70,
#   70,
#   69,
#   69,
#   71,
#   70,
#   70,
#   69,
#   70,
#   73,
#   70,
#   70,
#   69,
#   70,
#   69,
#   69,
#   71,
#   69,
#   70,
#   69,
#   73,
#   69,
#   69,
#   69,
#   69,
#   70,
#   71,
#   73,
#   70,
#   69,
#   74,
#   70,
#   72,
#   38,
#   37,
#   38,
#   38,
#   38,
#   37,
#   37,
#   38,
#   38,
#   39,
#   37,
#   38,
#   38,
#   41,
#   40,
#   37,
#   37,
#   37,
#   37,
#   42,
#   37,
#   38,
#   39,
#   40,
#   40,
#   39,
#   37,
#   38,
#   37,
#   37,
#   37,
#   38,
#   38,
#   39,
#   42,
#   37,
#   38,
#   57,
#   21,
#   21,
#   21,
#   21,
#   20,
#   21,
#   21,
#   22,
#   21,
#   23,
#   25,
#   21,
#   22,
#   23,
#   21,
#   20,
#   21,
#   22,
#   25,
#   21,
#   32,
#   32,
#   32,
#   34,
#   34,
#   34,
#   33,
#   32,
#   35,
#   32,
#   32,
#   36,
#   32,
#   32,
#   33,
#   34,
#   32,
#   33,
#   34,
#   33,
#   32,
#   32,
#   32,
#   32,
#   33,
#   32,
#   34,
#   36,
#   33,
#   32,
#   32,
#   65,
#   35,
#   34,
#   35,
#   35,
#   35,
#   37,
#   37,
#   37,
#   36,
#   35,
#   38,
#   35,
#   35,
#   39,
#   35,
#   35,
#   36,
#   37,
#   35,
#   36,
#   37,
#   36,
#   35,
#   35,
#   35,
#   35,
#   36,
#   35,
#   37,
#   35,
#   39,
#   36,
#   35,
#   35,
#   32,
#   ...],
#  '011 101 110': [8,
#   22,
#   27,
#   11,
#   32,
#   44,
#   16,
#   30,
#   26,
#   51,
#   51,
#   17,
#   15,
#   52,
#   33,
#   23,
#   46,
#   45,
#   44,
#   45,
#   45,
#   45,
#   46,
#   44,
#   45,
#   45,
#   45,
#   47,
#   45,
#   45,
#   44,
#   47,
#   23,
#   32,
#   33,
#   31,
#   7,
#   19,
#   24,
#   21,
#   45,
#   31,
#   31,
#   58,
#   58,
#   58,
#   57,
#   58,
#   58,
#   22,
#   40,
#   25,
#   17,
#   17,
#   24,
#   20,
#   18,
#   44,
#   55,
#   54,
#   51,
#   17,
#   30,
#   14,
#   14,
#   18,
#   18,
#   17,
#   35,
#   33,
#   31,
#   17]}

# %%
df["nodes"]
# Out:
# 0          [1, 199, 352]
# 1          [1, 199, 203]
# 2          [1, 199, 200]
# 3          [1, 199, 198]
# 4          [1, 199, 197]
#               ...
# 13145    [673, 678, 676]
# 13146    [673, 678, 675]
# 13147    [673, 677, 676]
# 13148    [673, 677, 675]
# 13149    [673, 676, 675]
# Name: nodes, Length: 13150, dtype: object

# %%
CHOICE = [384, 389, 388]

# %%
def does_df_contain_motif(df, motif):
    motif = list(map(str, motif))
    return df[df["nodes"].isin([motif])].shape[0] > 0

CHOICE = list(map(str, CHOICE))
assert does_df_contain_motif(df, CHOICE), "Did not match an occurrence!"

# %%
graphlet_classes = list(df.groupby("graphlet_class").agg(lambda i: None).index)
graphlet_classes
# Out:
# ['011 100 100', '011 101 110']

# %%
from scipy.stats import mannwhitneyu
from statistics import median
from tqdm import tqdm
import pandas as pd

from pmotifs.graphlet_representation import graphlet_class_to_name

original_distribution = extract_metric_distribution(df, METRIC_NAME)

data = {}
for graphlet_class in graphlet_classes:
    data[graphlet_class] = []
    for r_df in tqdm(randomized_results.values(), desc=f"Loading {graphlet_class}"):
        random_distribution = extract_metric_distribution(r_df, METRIC_NAME)

        mwu_result = mannwhitneyu(
            original_distribution[graphlet_class],
            random_distribution[graphlet_class],
        )

        data[graphlet_class].append({
           "u-statistic": mwu_result.statistic,
           "p-value": mwu_result.pvalue,
           "sample-size": len(random_distribution[graphlet_class]),
           "sample-median": median(random_distribution[graphlet_class]),
           "original-size": len(original_distribution[graphlet_class]),
           "original-median": median(original_distribution[graphlet_class]),
       })

result_dfs = {
    graphlet_class: pd.DataFrame(d)
    for graphlet_class, d in data.items()
}
# Out:
# Loading 011 100 100: 100%|██████████████████| 1000/1000 [00:20<00:00, 49.64it/s]
# Loading 011 101 110: 100%|█████████████████| 1000/1000 [00:05<00:00, 168.38it/s]

# %%
def echo_results(df, alpha_global=0.05):
    # Bonferroni Correction
    alpha_local = alpha_global / df.shape[0]

    rejected_rows = df[df["p-value"] < alpha_local]
    print(f"The original is not like the random in {rejected_rows.shape[0]} of {df.shape[0]} cases!")

# %%
import matplotlib.pyplot as plt

def plot_results(df, graphlet_class):
    fig, (size_ax, median_ax) = plt.subplots(1,2, figsize=(10, 5))

    df[["sample-size"]].plot.hist(ax=size_ax)
    size_ax.axvline(result_df["original-size"][0], label="original", color="tab:orange")
    size_ax.set_title("sample-size")
    size_ax.legend()
    size_ax.set_xlabel(METRIC_NAME)

    df[["sample-median"]].plot.hist(ax=median_ax)
    median_ax.axvline(result_df["original-median"][0], label="original", color="tab:orange")
    median_ax.set_title("sample-median")
    median_ax.legend()
    median_ax.set_xlabel(METRIC_NAME)
    
    fig.suptitle(graphlet_class_to_name(graphlet_class))

# %%
for graphlet_class, result_df in result_dfs.items():
    print(graphlet_class_to_name(graphlet_class))
    echo_results(result_df)
    plot_results(result_df,graphlet_class)
    print()
# Out:
# 3-Dash
# The original is not like the random in 1000 of 1000 cases!
#
# Triangle
# The original is not like the random in 1000 of 1000 cases!
