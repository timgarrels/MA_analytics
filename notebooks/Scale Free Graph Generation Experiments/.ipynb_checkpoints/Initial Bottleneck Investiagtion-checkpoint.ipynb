# %%
import networkx as nx
import pandas as pd
import os

from pmotifs.config.config import DATASET_DIRECTORY


OUT = DATASET_DIRECTORY / "random_graphs"
g_ps = [g_p for g_p in os.listdir(OUT) if g_p[:2] == "0_"]


data = []
for g_p in g_ps:
    g = nx.read_edgelist(OUT / g_p)
    data.append({
        "name": g_p,
        "nodes": g.number_of_nodes(),
        "edges": g.number_of_edges(),
    })
pd.DataFrame(data).sort_values(by="name")
# Out:
#                                name  nodes  edges
# 5       0_barabasi_albert_graph_m_1   1000    999
# 0       0_barabasi_albert_graph_m_2   1000   1996
# 2       0_barabasi_albert_graph_m_3   1000   2991
# 1       0_ferdos_renyi_graph_m_2000   1000   2345
# 6  0_scale_free_graph_a_28_b_7_g_02   1000   1994
# 3  0_scale_free_graph_a_35_b_3_g_35   1000   1365
# 4  0_scale_free_graph_a_65_b_1_g_25   1000   1090

# %%
from tqdm import tqdm


def get_exclusive_neigborhood(g, vertex, nodes):
    vertex_neighbors = g.neighbors(vertex)
    subgraph_neighbors = set()
    for n in nodes:
        subgraph_neighbors.update(g.neighbors(n))
    return list(set(vertex_neighbors) - subgraph_neighbors)
        

def enumerate_subgraphs(g: nx.Graph, k: int):
    subgraphs = []
    def extend_subgraph(v_subgraph, v_extension, v):
        if len(v_subgraph) == k:
            subgraphs.append(v_subgraph)
            return

        while len(v_extension) != 0:
            w = v_extension.pop()
            
            exlusive_w_neighborhood = get_exclusive_neigborhood(g, w, v_subgraph)
            extension_set_additions = [n for n in exlusive_w_neighborhood if n > v]
            extend_subgraph(
                v_subgraph + [w],
                list(set(v_extension + extension_set_additions)),
                v,
            )
            

    for v in tqdm(g.nodes, desc=f"Walking over nodes {k}", leave=False):
        v_extension = [n for n in g.neighbors(v) if n > v]
        extend_subgraph([v], v_extension, v)
    return subgraphs

# %%
data = []
for g_p in tqdm(g_ps, desc="Walking over graphs", leave=False):
    g = nx.read_edgelist(OUT / g_p)
    
    subgraphs_3 = enumerate_subgraphs(g, 3)    
    subgraphs_4 = enumerate_subgraphs(g, 4)
    
    
    
    data.append({
        "name": g_p,
        "nodes": g.number_of_nodes(),
        "edges": g.number_of_edges(),
        "# 3 subgraphs": len(subgraphs_3),
        "# 4 subgraphs": len(subgraphs_4),
    })
pd.DataFrame(data).sort_values(by="name")
# Out:
# Walking over graphs:   0%|                                                          | 0/7 [00:00<?, ?it/s]
# Walking over nodes 3:   0%|                                                      | 0/1000 [00:00<?, ?it/s]
# Walking over nodes 3:  23%|█████████▋                                | 230/1000 [00:00<00:00, 2292.44it/s]
#
# Walking over nodes 4:   0%|                                                      | 0/1000 [00:00<?, ?it/s]
# Walking over nodes 4:   0%|                                              | 1/1000 [00:00<02:36,  6.38it/s]
# Walking over nodes 4:   0%|                                              | 2/1000 [00:00<05:14,  3.17it/s]
# Walking over nodes 4:   4%|██                                           | 45/1000 [00:00<00:10, 90.33it/s]
# Walking over nodes 4:   6%|██▊                                          | 63/1000 [00:01<00:15, 59.33it/s]
# Walking over nodes 4:   8%|███▍                                         | 76/1000 [00:01<00:15, 60.80it/s]
# Walking over nodes 4:  14%|██████                                     | 140/1000 [00:01<00:06, 143.33it/s]
# Walking over nodes 4:  16%|███████                                    | 163/1000 [00:01<00:05, 157.39it/s]
# Walking over nodes 4:  23%|█████████▊                                 | 229/1000 [00:01<00:03, 244.52it/s]
# Walking over nodes 4:  36%|███████████████▌                           | 361/1000 [00:01<00:01, 467.36it/s]
# Walking over nodes 4:  58%|█████████████████████████                  | 583/1000 [00:01<00:00, 779.53it/s]
# Walking over graphs:  14%|███████▏                                          | 1/7 [00:02<00:13,  2.18s/it]
# Walking over nodes 3:   0%|                                                      | 0/1000 [00:00<?, ?it/s]
#
# Walking over nodes 4:   0%|                                                      | 0/1000 [00:00<?, ?it/s]
# Walking over nodes 4:  32%|█████████████▎                            | 317/1000 [00:00<00:00, 3125.88it/s]
# Walking over nodes 4:  63%|██████████████████████████▍               | 630/1000 [00:00<00:00, 3115.08it/s]
# Walking over graphs:  29%|██████████████▎                                   | 2/7 [00:02<00:05,  1.09s/it]
# Walking over nodes 3:   0%|                                                      | 0/1000 [00:00<?, ?it/s]
# Walking over nodes 3:  19%|███████▉                                  | 188/1000 [00:00<00:00, 1857.82it/s]
#
# Walking over nodes 4:   0%|                                                      | 0/1000 [00:00<?, ?it/s]
# Walking over nodes 4:   0%|                                              | 1/1000 [00:01<19:30,  1.17s/it]
# Walking over nodes 4:   0%|                                              | 2/1000 [00:01<09:54,  1.68it/s]
# Walking over nodes 4:   0%|▏                                             | 3/1000 [00:01<06:17,  2.64it/s]
# Walking over nodes 4:   0%|▏                                             | 4/1000 [00:01<04:30,  3.68it/s]
# Walking over nodes 4:   1%|▍                                             | 9/1000 [00:01<01:25, 11.60it/s]
# Walking over nodes 4:   2%|▊                                            | 19/1000 [00:01<00:33, 28.95it/s]
# Walking over nodes 4:   4%|█▊                                           | 40/1000 [00:01<00:14, 68.33it/s]
# Walking over nodes 4:   8%|███▋                                        | 85/1000 [00:02<00:07, 118.83it/s]
# Walking over nodes 4:  10%|████▍                                        | 98/1000 [00:02<00:09, 95.32it/s]
# Walking over nodes 4:  11%|████▊                                       | 109/1000 [00:02<00:10, 88.33it/s]
# Walking over nodes 4:  14%|██████                                     | 141/1000 [00:02<00:06, 132.03it/s]
# Walking over nodes 4:  16%|██████▊                                    | 157/1000 [00:02<00:08, 102.83it/s]
# Walking over nodes 4:  19%|████████                                   | 188/1000 [00:03<00:07, 103.27it/s]
# Walking over nodes 4:  20%|████████▊                                   | 201/1000 [00:03<00:09, 80.07it/s]
# Walking over nodes 4:  21%|█████████▎                                  | 211/1000 [00:03<00:10, 73.26it/s]
# Walking over nodes 4:  25%|██████████▌                                | 246/1000 [00:03<00:07, 104.55it/s]
# Walking over nodes 4:  26%|███████████▏                               | 259/1000 [00:03<00:06, 106.09it/s]
# Walking over nodes 4:  29%|████████████▌                              | 293/1000 [00:04<00:04, 149.32it/s]
# Walking over nodes 4:  32%|█████████████▉                             | 325/1000 [00:04<00:03, 183.50it/s]
# Walking over nodes 4:  40%|█████████████████▎                         | 404/1000 [00:04<00:01, 322.91it/s]
# Walking over nodes 4:  47%|████████████████████▎                      | 472/1000 [00:04<00:01, 408.91it/s]
# Walking over nodes 4:  57%|████████████████████████▍                  | 568/1000 [00:04<00:00, 543.56it/s]
# Walking over nodes 4:  67%|████████████████████████████▋              | 668/1000 [00:04<00:00, 652.70it/s]
# Walking over nodes 4:  74%|███████████████████████████████▊           | 739/1000 [00:04<00:00, 632.86it/s]
# Walking over graphs:  43%|█████████████████████▍                            | 3/7 [00:07<00:11,  2.88s/it]
# Walking over nodes 3:   0%|                                                      | 0/1000 [00:00<?, ?it/s]
# Walking over nodes 3:  39%|████████████████▎                         | 387/1000 [00:00<00:00, 3867.50it/s]
#
# Walking over nodes 4:   0%|                                                      | 0/1000 [00:00<?, ?it/s]
# Walking over nodes 4:   0%|                                              | 1/1000 [00:00<04:30,  3.70it/s]
# Walking over nodes 4:   0%|                                              | 2/1000 [00:00<04:59,  3.33it/s]
# Walking over nodes 4:   0%|▏                                             | 5/1000 [00:01<03:12,  5.18it/s]
# Walking over nodes 4:   1%|▎                                             | 8/1000 [00:01<01:51,  8.86it/s]
# Walking over nodes 4:   4%|█▊                                           | 39/1000 [00:01<00:18, 52.01it/s]
# Walking over nodes 4:   5%|██▏                                          | 48/1000 [00:01<00:18, 50.55it/s]
# Walking over nodes 4:   7%|███▏                                         | 70/1000 [00:01<00:11, 79.49it/s]
# Walking over nodes 4:   8%|███▋                                         | 81/1000 [00:01<00:12, 72.32it/s]
# Walking over nodes 4:  12%|█████▎                                     | 124/1000 [00:01<00:06, 132.47it/s]
# Walking over nodes 4:  14%|██████▏                                     | 141/1000 [00:02<00:12, 70.73it/s]
# Walking over nodes 4:  15%|██████▊                                     | 154/1000 [00:02<00:12, 67.82it/s]
# Walking over nodes 4:  18%|███████▊                                    | 178/1000 [00:02<00:09, 90.93it/s]
# Walking over nodes 4:  21%|████████▉                                  | 209/1000 [00:02<00:06, 126.69it/s]
# Walking over nodes 4:  23%|█████████▊                                 | 229/1000 [00:03<00:05, 139.34it/s]
# Walking over nodes 4:  25%|██████████▊                                | 252/1000 [00:03<00:04, 158.50it/s]
# Walking over nodes 4:  27%|███████████▋                               | 273/1000 [00:03<00:04, 152.39it/s]
# Walking over nodes 4:  31%|█████████████▎                             | 309/1000 [00:03<00:03, 199.35it/s]
# Walking over nodes 4:  39%|████████████████▋                          | 388/1000 [00:03<00:01, 342.67it/s]
# Walking over graphs:  57%|████████████████████████████▌                     | 4/7 [00:11<00:09,  3.23s/it]
# Walking over nodes 3:   0%|                                                      | 0/1000 [00:00<?, ?it/s]
#
# Walking over nodes 4:   0%|                                                      | 0/1000 [00:00<?, ?it/s]
# Walking over nodes 4:   0%|                                              | 1/1000 [00:00<04:47,  3.47it/s]
# Walking over nodes 4:  12%|████▉                                      | 115/1000 [00:00<00:02, 378.52it/s]
# Walking over nodes 4:  39%|████████████████▎                         | 388/1000 [00:00<00:00, 1130.54it/s]
# Walking over graphs:  71%|███████████████████████████████████▋              | 5/7 [00:11<00:04,  2.27s/it]
# Walking over nodes 3:   0%|                                                      | 0/1000 [00:00<?, ?it/s]
#
# Walking over nodes 4:   0%|                                                      | 0/1000 [00:00<?, ?it/s]
# Walking over nodes 4:   8%|███▍                                        | 77/1000 [00:00<00:01, 753.54it/s]
# Walking over graphs:  86%|██████████████████████████████████████████▊       | 6/7 [00:12<00:01,  1.57s/it]
# Walking over nodes 3:   0%|                                                      | 0/1000 [00:00<?, ?it/s]
# Walking over nodes 3:   0%|                                              | 1/1000 [00:00<08:47,  1.89it/s]
# Walking over nodes 3:   0%|                                              | 2/1000 [00:00<04:51,  3.42it/s]
# Walking over nodes 3:   0%|▏                                             | 3/1000 [00:01<07:20,  2.26it/s]
# Walking over nodes 3:   0%|▏                                             | 5/1000 [00:01<04:20,  3.83it/s]
# Walking over nodes 3:   4%|█▉                                           | 42/1000 [00:01<00:18, 52.82it/s]
# Walking over nodes 3:  10%|████▌                                      | 105/1000 [00:01<00:06, 144.16it/s]
# Walking over nodes 3:  14%|█████▊                                     | 135/1000 [00:01<00:05, 147.20it/s]
# Walking over nodes 3:  16%|██████▉                                    | 160/1000 [00:02<00:05, 164.21it/s]
# Walking over nodes 3:  34%|██████████████▍                            | 337/1000 [00:02<00:01, 491.11it/s]
# Walking over nodes 3:  46%|███████████████████▊                       | 462/1000 [00:02<00:00, 652.99it/s]
# Walking over nodes 3:  55%|███████████████████████▌                   | 547/1000 [00:02<00:00, 526.31it/s]
#
# Walking over nodes 4:   0%|                                                      | 0/1000 [00:00<?, ?it/s]
# Walking over nodes 4:   0%|                                           | 1/1000 [00:58<16:15:32, 58.59s/it]
# Walking over nodes 4:   0%|                                            | 2/1000 [01:08<8:15:13, 29.77s/it]
# Walking over nodes 4:   0%|▏                                          | 3/1000 [02:19<13:33:18, 48.95s/it]
# Walking over nodes 4:   0%|▏                                           | 4/1000 [02:21<8:25:06, 30.43s/it]
# Walking over nodes 4:   0%|▏                                           | 5/1000 [02:25<5:45:57, 20.86s/it]
# Walking over nodes 4:   1%|▍                                          | 10/1000 [02:27<1:40:44,  6.11s/it]
# Walking over nodes 4:   1%|▋                                            | 14/1000 [02:28<56:47,  3.46s/it]
# Walking over nodes 4:   2%|▋                                            | 15/1000 [02:29<50:52,  3.10s/it]
# Walking over nodes 4:   2%|▋                                            | 16/1000 [02:31<47:15,  2.88s/it]
# Walking over nodes 4:   2%|▊                                            | 18/1000 [02:32<35:07,  2.15s/it]
# Walking over nodes 4:   2%|█                                            | 23/1000 [02:34<18:52,  1.16s/it]
# Walking over nodes 4:   3%|█▎                                           | 28/1000 [02:34<10:48,  1.50it/s]
# Walking over nodes 4:   3%|█▍                                           | 33/1000 [02:34<07:36,  2.12it/s]
# Walking over nodes 4:   4%|█▋                                           | 37/1000 [02:36<07:42,  2.08it/s]
# Walking over nodes 4:   4%|█▋                                           | 38/1000 [02:37<07:15,  2.21it/s]
# Walking over nodes 4:   4%|█▊                                           | 39/1000 [02:38<08:07,  1.97it/s]
# Walking over nodes 4:   4%|█▉                                           | 42/1000 [02:39<08:02,  1.98it/s]
# Walking over nodes 4:   4%|██                                           | 45/1000 [02:40<06:54,  2.30it/s]
# Walking over nodes 4:   6%|██▋                                          | 60/1000 [02:40<02:06,  7.45it/s]
# Walking over nodes 4:   6%|██▉                                          | 65/1000 [02:46<06:18,  2.47it/s]
# Walking over nodes 4:   7%|███                                          | 69/1000 [02:51<09:18,  1.67it/s]
# Walking over nodes 4:   7%|███▏                                         | 72/1000 [02:53<09:06,  1.70it/s]
# Walking over nodes 4:  10%|████▌                                       | 103/1000 [02:53<02:20,  6.38it/s]
# Walking over nodes 4:  11%|████▉                                       | 111/1000 [03:03<05:58,  2.48it/s]
# Walking over nodes 4:  11%|████▉                                       | 112/1000 [03:05<06:26,  2.30it/s]
# Walking over nodes 4:  12%|█████▏                                      | 118/1000 [03:11<08:44,  1.68it/s]
# Walking over nodes 4:  12%|█████▎                                      | 122/1000 [03:16<10:31,  1.39it/s]
# Walking over nodes 4:  12%|█████▌                                      | 125/1000 [03:20<11:41,  1.25it/s]
# Walking over nodes 4:  13%|█████▌                                      | 127/1000 [03:21<11:20,  1.28it/s]
# Walking over nodes 4:  13%|█████▋                                      | 129/1000 [03:23<10:54,  1.33it/s]
# Walking over nodes 4:  13%|█████▊                                      | 131/1000 [03:25<11:52,  1.22it/s]
# Walking over nodes 4:  13%|█████▊                                      | 133/1000 [03:27<12:56,  1.12it/s]
# Walking over nodes 4:  13%|█████▉                                      | 134/1000 [03:28<13:13,  1.09it/s]
# Walking over nodes 4:  14%|█████▉                                      | 135/1000 [03:29<14:02,  1.03it/s]
# Walking over nodes 4:  14%|█████▉                                      | 136/1000 [03:30<11:48,  1.22it/s]
# Walking over nodes 4:  14%|██████                                      | 137/1000 [03:30<09:43,  1.48it/s]
# Walking over nodes 4:  14%|██████                                      | 139/1000 [03:31<09:03,  1.58it/s]
# Walking over nodes 4:  14%|██████▏                                     | 140/1000 [03:32<10:32,  1.36it/s]
# Walking over nodes 4:  14%|██████▏                                     | 141/1000 [03:33<11:23,  1.26it/s]
# Walking over nodes 4:  14%|██████▏                                     | 142/1000 [03:34<12:22,  1.16it/s]
# Walking over nodes 4:  14%|██████▎                                     | 143/1000 [03:35<13:32,  1.06it/s]
# Walking over nodes 4:  14%|██████▎                                     | 144/1000 [03:36<14:31,  1.02s/it]
# Walking over nodes 4:  14%|██████▍                                     | 145/1000 [03:37<14:22,  1.01s/it]
# Walking over nodes 4:  15%|██████▍                                     | 146/1000 [03:38<14:31,  1.02s/it]
# Walking over nodes 4:  15%|██████▌                                     | 148/1000 [03:39<11:08,  1.28it/s]
# Walking over nodes 4:  15%|██████▌                                     | 149/1000 [03:40<11:38,  1.22it/s]
# Walking over nodes 4:  15%|██████▌                                     | 150/1000 [03:41<11:57,  1.18it/s]
# Walking over nodes 4:  15%|██████▋                                     | 152/1000 [03:42<09:47,  1.44it/s]
# Walking over nodes 4:  15%|██████▋                                     | 153/1000 [03:43<10:28,  1.35it/s]
# Walking over nodes 4:  15%|██████▊                                     | 154/1000 [03:44<11:05,  1.27it/s]
# Walking over nodes 4:  16%|██████▊                                     | 155/1000 [03:45<11:31,  1.22it/s]
# Walking over nodes 4:  16%|██████▊                                     | 156/1000 [03:46<11:33,  1.22it/s]
# Walking over nodes 4:  16%|███████                                     | 160/1000 [03:47<06:18,  2.22it/s]
# Walking over nodes 4:  16%|███████▏                                    | 162/1000 [03:47<06:06,  2.29it/s]
# Walking over nodes 4:  16%|███████▏                                    | 163/1000 [03:48<06:49,  2.05it/s]
# Walking over nodes 4:  17%|███████▎                                    | 166/1000 [03:49<05:23,  2.58it/s]
# Walking over nodes 4:  17%|███████▎                                    | 167/1000 [03:50<06:13,  2.23it/s]
# Walking over nodes 4:  17%|███████▌                                    | 171/1000 [03:50<04:22,  3.16it/s]
# Walking over nodes 4:  17%|███████▌                                    | 173/1000 [03:51<04:31,  3.05it/s]
# Walking over nodes 4:  18%|███████▋                                    | 175/1000 [03:52<04:35,  3.00it/s]
# Walking over nodes 4:  31%|█████████████▋                              | 310/1000 [03:53<00:13, 52.01it/s]
# Walking over nodes 4:  32%|█████████████▊                              | 315/1000 [03:54<00:21, 31.44it/s]
# Walking over nodes 4:  32%|██████████████                              | 319/1000 [03:56<00:32, 20.85it/s]
# Walking over nodes 4:  32%|██████████████▏                             | 322/1000 [03:56<00:40, 16.74it/s]
# Walking over nodes 4:  33%|██████████████▌                             | 330/1000 [03:57<00:37, 18.00it/s]
# Walking over nodes 4:  33%|██████████████▋                             | 333/1000 [03:57<00:47, 14.15it/s]
# Walking over nodes 4:  34%|██████████████▋                             | 335/1000 [03:59<01:25,  7.80it/s]
# Walking over nodes 4:  34%|██████████████▊                             | 337/1000 [04:02<02:50,  3.88it/s]
# Walking over nodes 4:  34%|██████████████▊                             | 338/1000 [04:04<03:43,  2.97it/s]
# Walking over nodes 4:  34%|██████████████▉                             | 339/1000 [04:05<04:42,  2.34it/s]
# Walking over nodes 4:  34%|██████████████▉                             | 340/1000 [04:06<05:50,  1.88it/s]
# Walking over nodes 4:  34%|███████████████                             | 341/1000 [04:07<05:19,  2.06it/s]
# Walking over nodes 4:  34%|███████████████                             | 342/1000 [04:08<07:00,  1.57it/s]
# Walking over nodes 4:  34%|███████████████                             | 343/1000 [04:08<06:15,  1.75it/s]
# Walking over nodes 4:  34%|███████████████▏                            | 344/1000 [04:09<05:29,  1.99it/s]
# Walking over nodes 4:  34%|███████████████▏                            | 345/1000 [04:09<04:41,  2.32it/s]
# Walking over nodes 4:  35%|███████████████▏                            | 346/1000 [04:09<03:56,  2.76it/s]
# Walking over nodes 4:  35%|███████████████▎                            | 347/1000 [04:09<03:19,  3.27it/s]
# Walking over nodes 4:  35%|███████████████▎                            | 348/1000 [04:09<02:50,  3.82it/s]
# Walking over nodes 4:  35%|███████████████▎                            | 349/1000 [04:10<04:59,  2.17it/s]
# Walking over nodes 4:  35%|███████████████▍                            | 350/1000 [04:11<06:18,  1.72it/s]
# Walking over nodes 4:  35%|███████████████▍                            | 352/1000 [04:12<05:24,  2.00it/s]
# Walking over nodes 4:  35%|███████████████▌                            | 354/1000 [04:13<04:55,  2.19it/s]
# Walking over nodes 4:  36%|███████████████▊                            | 359/1000 [04:13<02:52,  3.71it/s]
# Walking over nodes 4:  44%|███████████████████▌                        | 444/1000 [04:15<00:17, 31.66it/s]
# Walking over nodes 4:  45%|███████████████████▊                        | 451/1000 [04:16<00:22, 23.96it/s]
# Walking over nodes 4:  46%|████████████████████▎                       | 461/1000 [04:17<00:33, 16.25it/s]
# Walking over nodes 4:  46%|████████████████████▎                       | 463/1000 [04:22<01:26,  6.20it/s]
# Walking over nodes 4:  46%|████████████████████▍                       | 465/1000 [04:24<02:04,  4.29it/s]
# Walking over nodes 4:  47%|████████████████████▌                       | 466/1000 [04:25<02:26,  3.64it/s]
# Walking over nodes 4:  47%|████████████████████▌                       | 467/1000 [04:27<02:51,  3.10it/s]
# Walking over nodes 4:  47%|████████████████████▌                       | 468/1000 [04:28<03:22,  2.63it/s]
# Walking over nodes 4:  47%|████████████████████▋                       | 469/1000 [04:29<03:56,  2.25it/s]
# Walking over nodes 4:  47%|████████████████████▋                       | 470/1000 [04:30<04:42,  1.88it/s]
# Walking over nodes 4:  47%|████████████████████▋                       | 471/1000 [04:31<05:20,  1.65it/s]
# Walking over nodes 4:  47%|████████████████████▊                       | 472/1000 [04:32<06:03,  1.45it/s]
# Walking over nodes 4:  47%|████████████████████▊                       | 473/1000 [04:33<06:42,  1.31it/s]
# Walking over nodes 4:  47%|████████████████████▊                       | 474/1000 [04:34<07:23,  1.19it/s]
# Walking over nodes 4:  48%|████████████████████▉                       | 475/1000 [04:35<07:39,  1.14it/s]
# Walking over nodes 4:  48%|████████████████████▉                       | 476/1000 [04:36<08:01,  1.09it/s]
# Walking over nodes 4:  48%|████████████████████▉                       | 477/1000 [04:37<08:10,  1.07it/s]
# Walking over nodes 4:  48%|█████████████████████                       | 478/1000 [04:38<08:07,  1.07it/s]
# Walking over nodes 4:  48%|█████████████████████                       | 479/1000 [04:39<08:01,  1.08it/s]
# Walking over nodes 4:  48%|█████████████████████                       | 480/1000 [04:40<07:56,  1.09it/s]
# Walking over nodes 4:  48%|█████████████████████▏                      | 481/1000 [04:41<07:43,  1.12it/s]
# Walking over nodes 4:  48%|█████████████████████▏                      | 482/1000 [04:42<07:34,  1.14it/s]
# Walking over nodes 4:  48%|█████████████████████▎                      | 483/1000 [04:42<07:26,  1.16it/s]
# Walking over nodes 4:  48%|█████████████████████▎                      | 484/1000 [04:43<07:19,  1.18it/s]
# Walking over nodes 4:  48%|█████████████████████▎                      | 485/1000 [04:44<07:13,  1.19it/s]
# Walking over nodes 4:  49%|█████████████████████▍                      | 486/1000 [04:45<07:08,  1.20it/s]
# Walking over nodes 4:  49%|█████████████████████▍                      | 487/1000 [04:46<07:06,  1.20it/s]
# Walking over nodes 4:  49%|█████████████████████▍                      | 488/1000 [04:47<07:00,  1.22it/s]
# Walking over nodes 4:  49%|█████████████████████▌                      | 489/1000 [04:47<07:01,  1.21it/s]
# Walking over nodes 4:  49%|█████████████████████▌                      | 490/1000 [04:48<07:00,  1.21it/s]
# Walking over nodes 4:  49%|█████████████████████▌                      | 491/1000 [04:49<06:59,  1.21it/s]
# Walking over nodes 4:  49%|█████████████████████▋                      | 492/1000 [04:50<06:55,  1.22it/s]
# Walking over nodes 4:  49%|█████████████████████▋                      | 493/1000 [04:51<06:44,  1.25it/s]
# Walking over nodes 4:  49%|█████████████████████▋                      | 494/1000 [04:51<06:32,  1.29it/s]
# Walking over nodes 4:  50%|█████████████████████▊                      | 495/1000 [04:52<06:24,  1.31it/s]
# Walking over nodes 4:  50%|█████████████████████▊                      | 496/1000 [04:53<06:17,  1.34it/s]
# Walking over nodes 4:  50%|█████████████████████▊                      | 497/1000 [04:54<06:23,  1.31it/s]
# Walking over nodes 4:  50%|█████████████████████▉                      | 498/1000 [04:54<06:26,  1.30it/s]
# Walking over nodes 4:  50%|█████████████████████▉                      | 499/1000 [04:55<06:20,  1.32it/s]
# Walking over nodes 4:  50%|██████████████████████                      | 500/1000 [04:56<06:15,  1.33it/s]
# Walking over nodes 4:  50%|██████████████████████                      | 501/1000 [04:56<06:10,  1.35it/s]
# Walking over nodes 4:  50%|██████████████████████                      | 502/1000 [04:57<06:04,  1.37it/s]
# Walking over nodes 4:  50%|██████████████████████▏                     | 503/1000 [04:58<05:58,  1.39it/s]
# Walking over nodes 4:  50%|██████████████████████▏                     | 504/1000 [04:59<05:52,  1.41it/s]
# Walking over nodes 4:  50%|██████████████████████▏                     | 505/1000 [04:59<05:40,  1.46it/s]
# Walking over nodes 4:  55%|████████████████████████▍                   | 554/1000 [04:59<00:14, 30.03it/s]
# Walking over nodes 4:  73%|███████████████████████████████▎           | 727/1000 [04:59<00:01, 155.12it/s]
# Walking over nodes 4:  77%|█████████████████████████████████▏         | 772/1000 [05:00<00:01, 143.28it/s]
# Walking over nodes 4:  82%|███████████████████████████████████▍       | 823/1000 [05:00<00:00, 178.71it/s]
# Walking over nodes 4:  88%|█████████████████████████████████████▋     | 876/1000 [05:00<00:00, 220.20it/s]
#                                name  nodes  edges  # 3 subgraphs  \
# 5       0_barabasi_albert_graph_m_1   1000    999           5150
# 0       0_barabasi_albert_graph_m_2   1000   1996          19612
# 2       0_barabasi_albert_graph_m_3   1000   2991          37123
# 1       0_ferdos_renyi_graph_m_2000   1000   2345          10865
# 6  0_scale_free_graph_a_28_b_7_g_02   1000   1994         208173
# 3  0_scale_free_graph_a_35_b_3_g_35   1000   1365          20389
# 4  0_scale_free_graph_a_65_b_1_g_25   1000   1090           8924
#
#    # 4 subgraphs
# 5          51246
# 0         380109
# 2         790576
# 1          67098
# 6       25258907
# 3         606794
# 4         131626

# %%
import matplotlib.pyplot as plt
from collections import defaultdict


fig, axes = plt.subplots(1, len(g_ps), figsize=(5 * len(g_ps), 5), sharey=True)


for i, g_p in enumerate(g_ps):
    ax = axes[i]
    
    g = nx.read_edgelist(OUT / g_p)
    
    degrees = defaultdict(lambda: 0)
    for _, degree in dict(g.degree).items():
        degrees[degree] += 1
        
    ax.bar(degrees.keys(), degrees.values())
    ax.set_title(g_p)
    
    ax.set_xlabel("degree")
    ax.set_ylabel("#")

# %%
# Degree of a node and his neighbors
import matplotlib.pyplot as plt
from collections import defaultdict


fig, axes = plt.subplots(1, len(g_ps), figsize=(5 * len(g_ps), 5), sharey=True)


for i, g_p in enumerate(g_ps):
    ax = axes[i]
    
    g = nx.read_edgelist(OUT / g_p)
    
    degrees = defaultdict(lambda: 0)
    for n in g.nodes:
        n_neighbors = g.neighbors(n)
        
        all_neighbors = set(n_neighbors)
        for neighbor in n_neighbors:
            all_neighbors.update(g.neighbors(neighbor))
        degrees[len(all_neighbors)] += 1

    ax.bar(degrees.keys(), degrees.values())
    ax.set_title(g_p)
    
    ax.set_xlabel("degree")
    ax.set_ylabel("#")

# %%
pd.DataFrame(data).sort_values(by="name")
# Out:
#                                name  nodes  edges  # 3 subgraphs  \
# 5       0_barabasi_albert_graph_m_1   1000    999           5150
# 0       0_barabasi_albert_graph_m_2   1000   1996          19612
# 2       0_barabasi_albert_graph_m_3   1000   2991          37123
# 1       0_ferdos_renyi_graph_m_2000   1000   2345          10865
# 6  0_scale_free_graph_a_28_b_7_g_02   1000   1994         208173
# 3  0_scale_free_graph_a_35_b_3_g_35   1000   1365          20389
# 4  0_scale_free_graph_a_65_b_1_g_25   1000   1090           8924
#
#    # 4 subgraphs
# 5          51246
# 0         380109
# 2         790576
# 1          67098
# 6       25258907
# 3         606794
# 4         131626

# %%
import matplotlib.pyplot as plt
from collections import defaultdict


fig, axes = plt.subplots(1, len(g_ps), figsize=(5 * len(g_ps), 5), sharey=True)


for i, g_p in enumerate(g_ps):
    ax = axes[i]
    
    g = nx.read_edgelist(OUT / g_p)
    
    avg_degree = dict(g.degree).values()
    avg_degree = sum(avg_degree) / len(avg_degree)
    print(g_p)
    print(avg_degree)
    print()
    print()
# Out:
# 0_barabasi_albert_graph_m_2
# 3.992
# 144
#
# 0_ferdos_renyi_graph_m_2000
# 4.69
# 72
#
# 0_barabasi_albert_graph_m_3
# 5.982
# 657
#
# 0_scale_free_graph_a_35_b_3_g_35
# 2.73
# 315
#
# 0_scale_free_graph_a_65_b_1_g_25
# 2.18
# 24
#
# 0_barabasi_albert_graph_m_1
# 1.998
# 0
#
# 0_scale_free_graph_a_28_b_7_g_02
# 3.988
# 5184

# %%
g_1 = nx.read_edgelist(OUT/"0_scale_free_graph_a_28_b_7_g_02")

g_2 = nx.read_edgelist(OUT/"0_scale_free_graph_a_35_b_3_g_35")

# %%
pos = nx.kamada_kawai_layout(g_1)
nx.draw(g_1, pos=pos)

# %%
pos_2 = nx.kamada_kawai_layout(g_2)
nx.draw(g_2, pos=pos_2)

# %% [markdown]
# # PREDICTION OVER CLIQUE COUNT?

# %%
data
# Out:
# [{'name': '0_barabasi_albert_graph_m_2',
#   'nodes': 1000,
#   'edges': 1996,
#   '# 3 subgraphs': 19612,
#   '# 4 subgraphs': 380109},
#  {'name': '0_ferdos_renyi_graph_m_2000',
#   'nodes': 1000,
#   'edges': 2345,
#   '# 3 subgraphs': 10865,
#   '# 4 subgraphs': 67098},
#  {'name': '0_barabasi_albert_graph_m_3',
#   'nodes': 1000,
#   'edges': 2991,
#   '# 3 subgraphs': 37123,
#   '# 4 subgraphs': 790576},
#  {'name': '0_scale_free_graph_a_35_b_3_g_35',
#   'nodes': 1000,
#   'edges': 1365,
#   '# 3 subgraphs': 20389,
#   '# 4 subgraphs': 606794},
#  {'name': '0_scale_free_graph_a_65_b_1_g_25',
#   'nodes': 1000,
#   'edges': 1090,
#   '# 3 subgraphs': 8924,
#   '# 4 subgraphs': 131626},
#  {'name': '0_barabasi_albert_graph_m_1',
#   'nodes': 1000,
#   'edges': 999,
#   '# 3 subgraphs': 5150,
#   '# 4 subgraphs': 51246},
#  {'name': '0_scale_free_graph_a_28_b_7_g_02',
#   'nodes': 1000,
#   'edges': 1994,
#   '# 3 subgraphs': 208173,
#   '# 4 subgraphs': 25258907}]

# %%
df = pd.DataFrame(data).sort_values(by="name")

# %%
c3s = []
c4s = []
for g_p in df["name"]:
    g = nx.read_edgelist(OUT / g_p)
    cliques = list(nx.enumerate_all_cliques(g))
    c3 = len([c for c in cliques if len(c) == 3])
    c4 = len([c for c in cliques if len(c) == 4])
    
    c3s.append(c3)
    c4s.append(c4)
    
df["# 3-Clique"] = c3s
df["# 4-Clique"] = c4s

df
# Out:
#                                name  nodes  edges  # 3 subgraphs  \
# 5       0_barabasi_albert_graph_m_1   1000    999           5150
# 0       0_barabasi_albert_graph_m_2   1000   1996          19612
# 2       0_barabasi_albert_graph_m_3   1000   2991          37123
# 1       0_ferdos_renyi_graph_m_2000   1000   2345          10865
# 6  0_scale_free_graph_a_28_b_7_g_02   1000   1994         208173
# 3  0_scale_free_graph_a_35_b_3_g_35   1000   1365          20389
# 4  0_scale_free_graph_a_65_b_1_g_25   1000   1090           8924
#
#    # 4 subgraphs  # 3-Clique  # 4-Clique
# 5          51246           0           0
# 0         380109          48           0
# 2         790576         219           8
# 1          67098          24           0
# 6       25258907        1728        1437
# 3         606794         105          10
# 4         131626           8           0

# %%
plt.scatter(
    df["# 3 subgraphs"],
    df["# 3-Clique"],
    label="3"
)

plt.legend()

# %%
plt.scatter(
    df["# 4 subgraphs"],
    df["# 4-Clique"],
    label="4"
)
plt.legend()

# %%
plt.scatter(
    df["# 4 subgraphs"],
    df["# 4-Clique"],
    label="4"
)

plt.scatter(
    df["# 3 subgraphs"],
    df["# 3-Clique"],
    label="3"
)

plt.legend()

plt.xscale("log")
